# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Евгения, привет!</b>
#
# Меня зовут Евгений Дащенко, и я буду проверять твой проект. Предлагаю общаться на «ты» 😊 Но если это не удобно - дай знать, и мы перейдем на "вы".
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных. Ты уже проделал большую работу над проектом, но давай сделаем его еще лучше. Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Критическая ошибка: ❌</b> Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Хорошо, но можно и лучше: ❗️</b> Так выделены небольшие замечания. Одна-два таких замечания в проекте допустимы, но если их будет больше - тебе будет необходимо внести исправления. Это как тестовое задание при приеме на работу: очень много мелких ошибок могут стать причиной отказа кандидату.
#
# </div>
#
# <div class="alert alert-success">
# <b>Все отлично: ✅</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# # Сборный проект "Интернет-магазин "Стримчик""
#
# ## Описание проекта
# В интернет-магазине "Стримчик" нам поручили выявить определяющие успешность игры закономерности, которые позволят сделать ставку на потенциально популярный продукт и спланировать рекламные кампании. У нас имеются данные за 2016-й год и наша задача- спланировать кампанию на 2017-й.
#
# Мы будем выполнять несколько шагов, а именно:
#  1. Подготовка данных +
#  2. Исследовательский анализ данных+
#  3. Составления портрета пользователя каждого региона +
#  4. Проверка двух гипотез
#  5. Написание общего вывода
#
#
# **Описание данных**
#
# - Name — название игры
# - Platform — платформа
# - Year_of_Release — год выпуска
# - Genre — жанр игры
# - NA_sales — продажи в Северной Америке (миллионы проданных копий)
# - EU_sales — продажи в Европе (миллионы проданных копий)
# - JP_sales — продажи в Японии (миллионы проданных копий)
# - Other_sales — продажи в других странах (миллионы проданных копий)
# - Critic_Score — оценка критиков (максимум 100)
# - User_Score — оценка пользователей (максимум 10)
# - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Здорово, когда есть вступление в сам проект, каждый сможет быстрее разобраться в концепции / деталях работы.
#
# </div>

# %% [markdown]
# # Шаг 1. Подготовка и изучение данных
#
# Первым делом мы должны изучить таблицу визуально. Познакомиться с ней.

# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st


data=pd.read_csv('games.csv') 
# чтение таблицы для тебя data=pd.read_csv('/datasest/games.csv')

display(data.head())
display(data.tail())
display(data.sample())
data.info()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN
#                                 Name Platform  Year_of_Release       Genre  \
# ...

# %% [markdown]
# **При "визуальном" изучении данных было решено:**
# + 1. заменить названия столбцов (привести к нижнему регистру);
# + 2. преобразование данные в нужные типы в столбцах (user_score - численный показатель, а имеет тип object - меняем на 'float', cтолбцы годы нужно перевести в datatime и выделить год выпуска, перевести рейтинг критиков в целочисленный
# + 3. Проверить пропущенные значения в названиях и жанрах - возможно убрать, потому что всего два значения отсуствуют.
# + 4. Проверить пропущенный значения в "годах выпуска"
# + 5. Проверить уникальные значения в жанрах и названиях платформ.
# + 6. Перевести название игр - в строчные, проверить уникальность.

# %%
# выполняем первый пункт
cols = data.columns.str.lower().tolist()  # список всех столбцов
data.columns = cols # передаем список названия столбцов в исходную таблицу
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Отличный способ заменить регистр в наших данных 👍
# </div>

# %%
# выполняем третий пункт- работа с пропусками в "названиях" и "жанрах"
data.query('name.isnull()')
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# В нашем случае, есть всего 2 такие строчки, мы не можем их заполнить самостоятельно и так как их очень мало (примерно 0,01% на всю таблицу) я их удалю.

# %%
data.dropna(subset=['name'], inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16444 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера: ❗️</b>
#
# Я бы рекомендовал не использовать атрибут `inplace`, так как в последующих обновлениях библотеки `pandas` он будет удален.
#
# Лучше всего переопределять переменные.
#
# </div>

# %%
# выполним четвертый пункт - работа со столбцами "год". Необходимо проверить пропущенные значения.
data.query('year_of_release.isnull()')
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# ...

# %% [markdown]
# В базе 269 пропусков (2%) по признаку "год выпуска".  видно что часть из них содержат пропуски в рейтингах и нулевые продажи в большинстве регионов. В нашем анализе эти даннные важны. Удалять данные мы не будем, но и заменить мы их не можем, даже если в названиях указан год (на разных платформах игры выходят в разные годы). Я предлагаю заменить эти данные на 0.

# %%
data['year_of_release'] = data['year_of_release'].fillna(0)
data.query('year_of_release.isnull()') #проверка
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %%
# переходим к выполнению пункта №2- замена типа данных в столбцах "year_of_release", "rating", "user_score"
data.year_of_release = data.year_of_release.astype('int64')
data.head()    # проверка
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# Переведем значения столбца "Рейтинг пользователей" в числовой формат. Но сначала проверим значение "tbd" в рейтинге.
#
# tbd означает "To Be Determined". Служит для отметки неясностей или пропусков, которые надо заполнить, в информации требований. To Be Determined, то есть "Будет определено". Очень часто подобное сокращение можно встретить в анонсах компьютерных игр в графе "Дата выхода". Когда разработчик той или иной игры уже сообщил о том, что она готовится к выходу, но пока еще не может назвать точную дату, именно это сокращение и используется.
#
# В нашем случае означает что рейтинг должны были определить но так и не сделали этого. Фактически рейтинг не известен - тоже самое что NaN. Это рейтинг пользователей который нам никак не спрогнозировать - величина фактически категоральная хоть и выражена в цифрах. Заменим "TBD" на NaN значения."

# %%
data.replace('tbd', np.nan, inplace=True)
data.user_score.unique()   # проверка
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6', '3.7',
#        '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9', '3.1',
#        '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3', '2.7',
#        '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0', '1.6',
#        '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3',
#        '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'], dtype=object)

# %%
data.user_score = data.user_score.astype('float')   # переведем столбец в числовой формат
data.user_score.dtype   # проверка
# Out:
# dtype('float64')

# %%
# Переходим к обработке данных rating
data.rating.unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %%
data.rating.value_counts(dropna=False)
# Out:
# NaN     6764
# E       3990
# T       2961
# M       1563
# E10+    1420
# EC         8
# K-A        3
# RP         3
# AO         1
# Name: rating, dtype: int64

# %% [markdown]
# «AO» («Adults Only 18+») — «Только для взрослых» - 1 игра.
#
# «RP» («Rating Pending») — «Рейтинг ожидается» - 1 игра.
#
# «EC» («Early childhood») — «Для детей младшего возраста» - 8 игр
#
# "K-A" ("Kids to Adults") - 3 игры
#
# Нам предстоит выяснить влияние рейтинг ESRB на продажи в отдельном регионе. Эти категории с незначительным кол-вом игр будут выбиваться из статистики своим малым весом, можно их либо удалить (нежелательно) либо привести к остальным категориям по правилам самой ESRB:
# - "K-A" ("Kids to Adults") = «E» («Everyone») — «Для всех»
# - «EC» («Early childhood») — «E» («Everyone») — «Для всех» (так же применимо, судя по описанию)
# - «RP» («Rating Pending») — «Рейтинг ожидается» = Nan (без рейтинга)
# - «AO» («Adults Only 18+») = «M» («Mature») — «Для взрослых» (для нашего случая допустимое предположение, тем более что это GTA San Andreas на Xbox, а рейтинг 18+ ставился преимущественно на игры для компьютеров)

# %%
data.loc[data.rating == 'AO']   # какая игра с единственным рейтингом 'АО'
# Out:
#                               name platform  year_of_release   genre  \
# 875  Grand Theft Auto: San Andreas       XB             2005  Action
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 875      1.26      0.61       0.0         0.09          93.0         8.6
#
#     rating
# 875     AO

# %%
#Переобозначим рейтинги игр

data.replace('K-A', 'E', inplace=True)
data.replace('EC', 'E', inplace=True)
data.replace('RP', np.nan, inplace=True)
data.replace('AO', 'M', inplace=True)
data.rating.unique() # проверка
# Out:
# array(['E', nan, 'M', 'T', 'E10+'], dtype=object)

# %% [markdown]
# Так как в будущем нам потребуется провести корреляцию по рэйтингам, то мы добавим столбец рейтинга в числовом формате, через словарь. Кроме того, все пропуски в столбцах рейтингов оставляем без изменений - удалять большой объем данных нет смысла, заменить отсутсвующие значения фактически категоральных переменных нет возможности. Заменили рейтинги ESRB на следующие числа:
#
# - 1 = «E» («Everyone») — «Для всех»
# - 2 = «E10+» («Everyone 10 and older») — «Для всех от 10 лет и старше»:
# - 3 = «T» («Teen») — «Подросткам»:
# - 4 = «M» («Mature») — «Для взрослых»

# %%
dict_rating = {'E':1, 'E10+':2,'T':3,'M':4}   # словарь для замены значений
data['rating_num'] = data.rating.map(dict_rating)
data.rating_num.unique()  # проверка
# Out:
# array([ 1., nan,  4.,  3.,  2.])

# %% [markdown]
# Переходим к выполнению пункта №5: Проверить **уникальные значения в жанрах и названиях платформ**. И во избежании пропуска дубликатов, по необходимости, переведем все названия в строчные

# %%
data.name.unique()   # названия игр
# Out:
# array(['Wii Sports', 'Super Mario Bros.', 'Mario Kart Wii', ...,
#        'Woody Woodpecker in Crazy Castle 5', 'LMA Manager 2007',
#        'Haitaka no Psychedelica'], dtype=object)

# %%
data.name = data.name.str.lower()   # названия игр переводим в строчные
data.name.unique()  # проверка
# Out:
# array(['wii sports', 'super mario bros.', 'mario kart wii', ...,
#        'woody woodpecker in crazy castle 5', 'lma manager 2007',
#        'haitaka no psychedelica'], dtype=object)

# %%
data.query('platform.isnull()')
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating, rating_num]
# Index: []

# %%
data.genre.unique() # все названия жанров
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
data.query('genre.isnull()')
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating, rating_num]
# Index: []

# %% [markdown]
# Названия жанров нет смысла оптимизировать.
#
# Проверим, имеются ли у нас дубликаты.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Расчет суммарных продаж

# %%
data['total_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales'] + data['other_sales']
data.sample()  # проверка
# Out:
#             name platform  year_of_release       genre  na_sales  eu_sales  \
# 1368  the sims 3      Wii             2010  Simulation      0.57      0.69
#
#       jp_sales  other_sales  critic_score  user_score rating  rating_num  \
# 1368       0.0         0.14           NaN         2.5      T         3.0
#
#       total_sales
# 1368          1.4

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Кстати мы можем применить метод `sum(axis=1)` к суммируемым столбцам.
#
# `df[['col1', 'col2', 'col3']].sum(axis=1)`
# </div>

# %%
# Сбросим индексы. 
data.reset_index(inplace = True, drop = True)
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      Wii             2006        Sports     41.36
# 1         super mario bros.      NES             1985      Platform     29.08
# 2            mario kart wii      Wii             2008        Racing     15.68
# 3         wii sports resort      Wii             2009        Sports     15.61
# 4  pokemon red/pokemon blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN    NaN
#
#    rating_num  total_sales
# 0         1.0        82.54
# 1         NaN        40.24
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16713 entries, 0 to 16712
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9946 non-null   object
#  11  rating_num       9946 non-null   float64
#  12  total_sales      16713 non-null  float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 1.7+ MB

# %% [markdown]
# ## Итог проведенной предобработки данных
# - Названия столбцов перевели в написание с маленькой буквы.
# - Проверили пропуски по названию игры и жанру - эти 2 записи удалили из базы
# - Проверили и удалили пропуски по признаку "год выпуска". Часть из них содержали пропуски в рейтингах и нулевые продажи в большинстве регионов.
# - Провели оценку возможности замены других пропущенных значений - большой объем данных отсутствует в части столбцов с рейтингами.
# - Решили замену отсутствующих значений не проводить, пока в этом не будет необходимости связанной с вычислениями и анализом данных в соответствующих заданиях. Большую часть ограничений по расчетам данных с NaN можно средствами pandas. Если проводить замену данных сейчас, то далее получим некорректые данные для одного из заданий.
# - Перевели данные "год выпуска" в формат "int64"
# - Провели анализ значений "TBD" в рейтинге, заменили его на NaN в соответствии со смыслом выражения "TBD" - рейтинг должен быть определен.
# - Провели анализ рейтинга ESRB, выяснили что есть рейтинги с единичными записями. Такие рейтинги заменили на ближайшие им соответсвующие по терминологии ESRB:
#    + "K-A" ("Kids to Adults") = «E» («Everyone») — «Для всех»
#    + «EC» («Early childhood») — «E» («Everyone») — «Для всех» (так же применимо, судя по описанию)
#    + «RP» («Rating Pending») — «Рейтинг ожидается» = Nan (без рейтинга)
#    + «AO» («Adults Only 18+») = «M» («Mature») — «Для взрослых».
# - Создание числовой аналог столбца рейтинга ESRB для возможности внести этот рейтинг в анализ корреляции.
#  - 1 = «E» («Everyone») — «Для всех»
#  - 2 = «E10+» («Everyone 10 and older») — «Для всех от 10 лет и старше»:
#  - 3 = «T» («Teen») — «Подросткам»:
#  - 4 = «M» («Mature») — «Для взрослых»
# - Все пропуски в столбцах рейтингов оставили без изменений - заменить отсутсвующие значения фактически категоральных переменных нет возможности.
# - Проверили названия игр, жанров, платформ, во избежании пропуска дубликатов, перевели названия игр в написание с маленькой буквы.
# - Проверили базу на наличие дубликатов - дубликатов нет.
# - Провели переиндексацию данных.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Достаточно детально изучили и подготовили наши первичные данные, давай теперь их обработаем.
# </div>

# %% [markdown]
# # Шаг 2. Исследовательский анализ данных
#
# На данном этапе, нам надо выполнить следующие пункты:
# 1. Узнать, сколько игр выпускалось в разные годы.
# 2. Посмотреть, как менялись продажи по платформам.
# 3. Выявить актуальный период, чтобы построить прогноз на 2017 год.
# 4. Исследовать, какие платформы лидируют по продажам, растут или падают.
# 5. Построить график  по глобальным продажам игр в разбивке поплатформам.
# 6. Посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков и построить диаграмму рассеяния, посчитать корреляцию между отзывами и продажами.
# 7. Посмотреть на общее распределение игр по жанрам.
#
# ### Количество игр выпускавшихся в разные годы

# %%
data.groupby('year_of_release').count() # посчитаем общее количество выпущенных игр по годам
# Out:
#                  name  platform  genre  na_sales  eu_sales  jp_sales  \
# year_of_release
# 0                 269       269    269       269       269       269
# 1980                9         9      9         9         9         9
# 1981               46        46     46        46        46        46
# 1982               36        36     36        36        36        36
# 1983               17        17     17        17        17        17
# 1984               14        14     14        14        14        14
# 1985               14        14     14        14        14        14
# 1986               21        21     21        21        21        21
# 1987               16        16     16        16        16        16
# 1988               15        15     15        15        15        15
# 1989               17        17     17        17        17        17
# 1990               16        16     16        16        16        16
# ...

# %% [markdown]
# В базе рассматриваются игры с 1980 по 2016 гг. Первые 10-12 лет количество игр не превышало 100 ед. Больше 100 игр в год стали выходить начиная с 1994 года. С другой стороны игры стали интересны системам рейтинга начиная с 1997 г. когда количество рейтингов стало около 20, к этому времени число игр приблизилось к отметке 300. С этой точки зрения актуальный период можно обозначить с 1997 по 2016 гг. Пик выхода игр пришелся на 2008 - 2009 гг. - 1425 игр.
#
# Оценим количество проданных игр за все периоды с помощью графика.

# %%
data.query('year_of_release >= 1994') \
    .groupby('year_of_release')['name'] \
    .count().plot(figsize=(10, 6), label='Игры', lw=3)
    
plt.title('Количество проданных игр по годам выпуска')
plt.xlabel('Год выпуска')
plt.ylabel('Количество игр, ед.')
plt.grid(axis='both')
plt.legend(loc='best');
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Здорово, когда график и его оси подписаны 😊👍
#
# Так быстрее понять о чем идёт речь на самом графике.
#
# </div>

# %% [markdown]
# При помощи графика и таблицы мы явно вилим, что рост продаж начался с 1994-1995 гг. (около 200 ед.). Пик продаж пришелся на 2008-2009 гг.(1425 ед.) После этого периода продажи игр стабильно снижаются.
#
# ### Изменение количества продаж по платформам
# - Выберем платформы с наибольшими глобальными продажами
# - Построим распределение по годам.
# - Определим характерный срок жизни платформ

# %%
# подготовим данные по продажам и годам выхода игр для каждой платформы
platform = data.pivot_table(
    index=['platform', 'year_of_release'], values=['total_sales'], aggfunc='sum')
platform.reset_index(inplace=True)
platform.sort_values(by='platform')
# Out:
#     platform  year_of_release  total_sales
# 0       2600                0        10.50
# 1       2600             1980        11.38
# 2       2600             1981        35.68
# 3       2600             1982        28.88
# 4       2600             1983         5.84
# ..       ...              ...          ...
# 244       XB             2003        55.04
# 252     XOne             2015        60.14
# 250     XOne             2013        18.96
# 251     XOne             2014        54.07
# 253     XOne             2016        26.15
#
# [254 rows x 3 columns]

# %%
#Посчитаем для каждой платформы суммарные продажи и количество лет существования на рынке (по данным на 2016 г.).
#Отсортиуем данные по убыванию кол-ва лет.
platform_year = platform.pivot_table(
    index=['platform'], values=['year_of_release', 'total_sales'], 
    aggfunc={'year_of_release': 'count', 'total_sales': 'sum'})

platform_year.columns = ['total_sales', 'year_count']  # переименовали столбцы

# расположение итоговых таблиц слева направо для лучше визуализации

styler_1 = platform_year.sort_values(by='year_count', ascending=False).style.set_table_attributes(
    "style='display:inline'").set_caption('Сортировка по кол-ву лет на рынке')
styler_2 = platform_year.sort_values(by='total_sales', ascending=False).style.set_table_attributes(
    "style='display:inline'").set_caption('Сортировка по объему продаж')

display(styler_1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_75c3b" style='display:inline'>
#   <caption>Сортировка по кол-ву лет на рынке</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75c3b_level0_col0" class="col_heading level0 col0" >total_sales</th>
#       <th id="T_75c3b_level0_col1" class="col_heading level0 col1" >year_count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >platform</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75c3b_level0_row0" class="row_heading level0 row0" >PC</th>
#       <td id="T_75c3b_row0_col0" class="data row0 col0" >259.520000</td>
#       <td id="T_75c3b_row0_col1" class="data row0 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_75c3b_level0_row1" class="row_heading level0 row1" >GB</th>
#       <td id="T_75c3b_row1_col0" class="data row1 col0" >255.460000</td>
# ...

# %%
display(styler_2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fcf23" style='display:inline'>
#   <caption>Сортировка по объему продаж</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcf23_level0_col0" class="col_heading level0 col0" >total_sales</th>
#       <th id="T_fcf23_level0_col1" class="col_heading level0 col1" >year_count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >platform</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcf23_level0_row0" class="row_heading level0 row0" >PS2</th>
#       <td id="T_fcf23_row0_col0" class="data row0 col0" >1255.770000</td>
#       <td id="T_fcf23_row0_col1" class="data row0 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_fcf23_level0_row1" class="row_heading level0 row1" >X360</th>
#       <td id="T_fcf23_row1_col0" class="data row1 col0" >971.420000</td>
# ...

# %% [markdown]
# Благодаря полученным данным, мы видим, что характерный "срок жизни" более менее успешных платформ - 10 лет(+/-2 года).
# ТОП-6 платформ по продажам за весь период наблюдений (По остальным платформам продажи меньше более чем в 2 раза от 6 позиции):
#
# 1. PS2 - 1233.6 млн.долл.
# 2. X360 - 961.2 млн.долл.
# 3. PS3 - 931.3 млн.долл.
# 4. Wii - 891.2 млн.долл.
# 5. DS - 802.8 млн.долл.
# 6. PS - 727.6 млн.долл.
#
# Для исследования я выбрала в качестве **актуального периода** последние 5 лет (с 2012 по 2016 гг). Выбрала именно эти годы, так как в него попадают  Для того, чтобы работать с "актуальными" данными, создадим базу.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
#
#
# В том числе мы могли посчитать срок жизни платформы – вычесть из максимальной даты минимальную по каждой платформе и затем усреднить получившиеся значения.
#
# </div>

# %%
# отфильтруем базу по актуальному периоду
games = data.query('year_of_release > 2011')
games.reset_index(inplace=True, drop=True)
display(games.head())
games.info()
# Out:
#                          name platform  year_of_release         genre  \
# 0          grand theft auto v      PS3             2013        Action
# 1          grand theft auto v     X360             2013        Action
# 2   call of duty: black ops 3      PS4             2015       Shooter
# 3         pokemon x/pokemon y      3DS             2013  Role-Playing
# 4  call of duty: black ops ii      PS3             2012       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0      7.02      9.09      0.98         3.96          97.0         8.2      M
# 1      9.66      5.14      0.06         1.41          97.0         8.1      M
# 2      6.03      5.86      0.36         2.38           NaN         NaN    NaN
# 3      5.28      4.19      4.35         0.78           NaN         NaN    NaN
# 4      4.99      5.73      0.65         2.42          83.0         5.3      M
#
#    rating_num  total_sales
# 0         4.0        21.05
# ...

# %% [markdown]
# ### Лидеры продаж
# Выберем 10 самых продаваемых платформ за 2012-2016 гг.

# %%
# таблица суммарных продаж по платформам.
platform_sales = games.pivot_table(
    index=['platform'], values=['total_sales'], aggfunc='sum')
platform_sales_top10 = platform_sales.sort_values(by='total_sales', ascending=False).head(10)

platform_sales_top10  # ТОП-10 платформ по продажам во всех регионах
# Out:
#           total_sales
# platform
# PS4            314.14
# PS3            288.79
# X360           236.54
# 3DS            194.61
# XOne           159.32
# WiiU            82.19
# PC              62.65
# PSV             49.18
# Wii             35.37
# DS              12.55

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Кстати можно было бы также визуализировать эти таблицы, ведь на графике информацию воспринимать гораздо легче, чем в таблице.
# </div>

# %% [markdown]
# Создадим базу ТОП-10 самых продаваемых платформ за 2012-2016 г.

# %%
cols_top10 = platform_sales_top10.index.tolist()  # создадим список ТОП-10 платформ
cols_top10
# Out:
# ['PS4', 'PS3', 'X360', '3DS', 'XOne', 'WiiU', 'PC', 'PSV', 'Wii', 'DS']

# %%
filter_platform_top10 = games['platform'].isin(cols_top10)

# отфильтруем общую базу по платформам из ТОП-10 продаж
platform_top10 = games[filter_platform_top10]
platform_top10.head()   # проверка
# Out:
#                          name platform  year_of_release         genre  \
# 0          grand theft auto v      PS3             2013        Action
# 1          grand theft auto v     X360             2013        Action
# 2   call of duty: black ops 3      PS4             2015       Shooter
# 3         pokemon x/pokemon y      3DS             2013  Role-Playing
# 4  call of duty: black ops ii      PS3             2012       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0      7.02      9.09      0.98         3.96          97.0         8.2      M
# 1      9.66      5.14      0.06         1.41          97.0         8.1      M
# 2      6.03      5.86      0.36         2.38           NaN         NaN    NaN
# 3      5.28      4.19      4.35         0.78           NaN         NaN    NaN
# 4      4.99      5.73      0.65         2.42          83.0         5.3      M
#
#    rating_num  total_sales
# 0         4.0        21.05
# ...

# %% [markdown]
# Теперь построим график ТОП-10 платформ, но для начала нам необходимо подготовить данные.

# %%
platform_year_top10 = platform_top10.pivot_table(
    index=['platform', 'year_of_release'], values=['total_sales'], aggfunc='sum')
platform_year_top10    # сводная таблица продаж ТОП-10 платформ по годам
# Out:
#                           total_sales
# platform year_of_release
# 3DS      2012                   51.36
#          2013                   56.57
#          2014                   43.76
#          2015                   27.78
#          2016                   15.14
# DS       2012                   11.01
#          2013                    1.54
# PC       2012                   23.22
#          2013                   12.38
#          2014                   13.28
#          2015                    8.52
#          2016                    5.25
# PS3      2012                  107.36
#          2013                  113.25
#          2014                   47.76
#          2015                   16.82
#          2016                    3.60
# PS4      2013                   25.99
#          2014                  100.00
#          2015                  118.90
#          2016                   69.25
# PSV      2012                   16.19
#          2013                   10.59
# ...

# %%
# Таблица продаж ТОП-10 платформ по годам для построения общего графика

platform_top10_plot = platform_year_top10.pivot_table(
    index='year_of_release', columns='platform', values=['total_sales'], fill_value=0)
platform_top10_plot
# Out:
#                 total_sales                                              \
# platform                3DS     DS     PC     PS3     PS4    PSV    Wii
# year_of_release
# 2012                  51.36  11.01  23.22  107.36    0.00  16.19  21.71
# 2013                  56.57   1.54  12.38  113.25   25.99  10.59   8.59
# 2014                  43.76   0.00  13.28   47.76  100.00  11.90   3.75
# 2015                  27.78   0.00   8.52   16.82  118.90   6.25   1.14
# 2016                  15.14   0.00   5.25    3.60   69.25   4.25   0.18
#
#
# platform          WiiU   X360   XOne
# year_of_release
# 2012             17.56  99.74   0.00
# 2013             21.65  88.58  18.96
# 2014             22.03  34.74  54.07
# 2015             16.35  11.96  60.14
# 2016              4.60   1.52  26.15

# %% [markdown]
# **График глобальных продаж ТОП-10 платформ за период 2012-2016 гг.**

# %%
platform_top10_plot.plot(figsize=(10, 6), lw=3)
plt.title('Глобальные продажи по всем регионам игр из ТОП-10 платформ')
plt.xlabel('Год выпуска')
plt.ylabel('Сумма, млн. долл.')
plt.grid(axis='both')
plt.legend(bbox_to_anchor=(1, 1));

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера: ❗️</b>
#
# Обрати внимание, что график не совсем читабелен, потому что включает в себя много линий. Обычно используют 2-3 линии максимум на одном графике, чтобы повысить комфортность изучения графика.
#
# Рекомендовал бы посмотреть каждую платформу на отдельном графике или использовать метод `subplots` построив графики в 2 столбца например.
#
# https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html
#
# </div>

# %% [markdown]
# На графике чётко видно, что по всем платформам из ТОП-10 глобальных продаж общая выручка к 2016 году стабильно снижается.
#
# **Диаграмма размаха по глобальным продажам игр ТОП-10 платформам.**

# %%
plt.figure(figsize=(12, 10))
plt.ylim(0, 2)
sns.boxplot(x="platform", y="total_sales", data=platform_top10, palette='rainbow')
plt.title('Диаграмма размаха по глобальным продажам ТОП-10 платформ\n  ', fontsize=14)
plt.ylabel('Сумма, сотни млн. долл.')
plt.xlabel('Игровая платформа');

# %% [markdown]
# В период 2012-2016 гг. по всем платформам снижается глобальная выручка, в том числе в ТОР10 платформ. Самыми успешными по продажам в эти 5 лет были Х360, PS3, PS4, XOne и Wii. Медианные значения у этой группы выше чем у остальных - значит снижение продаж было либо позже чем у остальных, либо не таким резким было падение.
#
#
# Теперь рассмотрим **как влияют отзывы покупателей и критиков** на продажи. Для этого нам необходимо:
# - построить диаграмму рассеивания
# - посчитать корреляцию
# + сделать выводы
#
# для анализа я возьму самую продаваемую платформу- **PS4**

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Отличный способ визуализировать разброс данных по каждой платформе 👍
#
# Кстати мы можем использовать параметр `showfliers=False`, чтобы убрать выбросы с графика.
#
# </div>

# %%
# фильтр для отбора игр этой платформы из общей базы ТОП-10
filter_platform_PS4 = platform_top10['platform'].isin(['PS4'])
platform_PS4 = platform_top10[filter_platform_PS4]
platform_PS4.head()   # проверка
# Out:
#                               name platform  year_of_release    genre  \
# 2        call of duty: black ops 3      PS4             2015  Shooter
# 6               grand theft auto v      PS4             2014   Action
# 14                         fifa 16      PS4             2015   Sports
# 17    star wars battlefront (2015)      PS4             2015  Shooter
# 18  call of duty: advanced warfare      PS4             2014  Shooter
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 2       6.03      5.86      0.36         2.38           NaN         NaN
# 6       3.96      6.31      0.38         1.97          97.0         8.3
# 14      1.12      6.12      0.06         1.28          82.0         4.3
# 17      2.99      3.49      0.22         1.28           NaN         NaN
# 18      2.81      3.48      0.14         1.23          83.0         5.7
#
#    rating  rating_num  total_sales
# 2     NaN         NaN        14.63
# 6       M         4.0        12.62
# ...

# %%
# выберем данные по которым строим диаграмму
cols = ['total_sales', 'critic_score', 'user_score', 'rating_num']
sns.set(style="ticks", color_codes=True)
sns_plot = sns.pairplot(platform_PS4[cols]);

# %% [markdown]
# ### Анализ диаграммы рассеяния:
# Связь между объемами продаж и отзывами критиков и пользователей заметная - лучше продаются те игры на которые больше положительных отзывов. Есть положительные отзывы на малопродаваемые игры.
#
# Отзывы критиков и пользователей связаны - скорее всего связь такая - пользователи по высоким рекомендациям критиков покупают игры и затем их же оценивают. Соответственно, те игры где оценки критики невысокие - не попадают в поле зрения массового пользователя.
#
# В основном отзывы критиков и пользователей это показатели оценок выше среднего, примерно 3/4 от максимума
# Встречаются высокие единичные оценки на игры которые плохо продаются.
# По рейтингу ESRB следующая картина:
# 1. категория «Для всех»
# + третьи в продажах
# + вторые по отзывам критиков
# 2. категория «Для всех от 10 лет и старше»
# + самые низкие продажи
# + меньше всего отзывов критиков и пользователей
# 3.  категория «Подросткам»
# + больше всего в количестве проданных игр
# 4.  категория «Для взрослых»
# + вторые по кол-ву проданных игр
# + первые по объему продаж
# + больше всего отзывов критиков
#
# **Диаграмма взаимных корреляций, по игровой платформе PS4, данных по продажам и рейтингам критиков, пользователей и ESRB**

# %%
correlation = platform_PS4.corr()
plt.figure(figsize=(12, 12))
sns.heatmap(correlation, vmax=1, square=True, annot=True, cmap='mako')
plt.title('Диаграмма взаимных корреляций, данные по игровой платформе PS4\n    ', fontsize=14);

# %% [markdown]
# ## Анализ диаграммы корреляций:
# - Высокое значение корреляции между общими продажами и продажами по Северной Америке, Европе = 0,93 - 0,96.
# - Прямая зависимость общих продаж от продаж в других странах
# - По Японии показатель слабый = 0,53. Следовательно Япония вносит заметно меньший вклад в суммарные продажи по всему миру, в отличии от остальных регионов.
# - Влияние отзывов критиков на продажи есть, но не такое явное как предполагалось по диаграммам рассеяния. По всем регионам и по общим продажам оно в пределах 0,35-0,42 ед.
# - В Японии влияние каких-либо рейтингов на продажи игр мало.
# - Отзывы критиков действительно не сильно влияют на оценки пользователей - тут коэф. корреляции = 0,56.
# - По рейтингу ESRB не оказывает заметного влияния на другие показатели, что естественно потому что носит информативный характер в выборе игр.
#
# **Анализ влияния отзывов пользователей и критиков на продажи остальных платформ из ТОП-10**
# - Построим диаграмму рассеяния
# - Посчитаем корреляцию между отзывами и продажами.
# - Сделаем выводы.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Хорошие и логичные комментарии. Очень важно строить график корреляции между переменными, ведь может произойти такая ситуация, что расчет у нас очень сильный а на графике абсолютно другая картина.
#
#
# </div>

# %%
# Фильтруем данные по признаку - "все платформы кроме PS4"

platform_top10_other = platform_top10[~filter_platform_PS4]
platform_top10_other.platform.unique() # проверка
# Out:
# array(['PS3', 'X360', '3DS', 'DS', 'XOne', 'WiiU', 'Wii', 'PC', 'PSV'],
#       dtype=object)

# %%
# Диаграмма рассеяния по другим платформам

sns.set(style="ticks", color_codes=True)
sns_plot = sns.pairplot(platform_top10_other[cols])

# %% [markdown]
# ### Анализ диаграммы рассеяния -- Другие платформы vs PS4:
# - Аналогично связь между объемами продаж и отзывами критиков и пользователей заметная - лучше продаются те игры на которые больше положительных отзывов.
# - Также отзывы критиков и пользователей заметно связаны. Тот же широкий охват вариаций рейтингов, прибавился объем низких рейтингов и отзывов на игры.
# - В этом случае основные отзывы критиков и пользователей это показатели оценок выше среднего и до 3/4 от максимума.
# - Также встречаются высокие единичные оценки на игры которые плохо продаются.
# - По рейтингу ESRB следующая картина:
# 1. категория «Для всех»
# - вторые в продажах (в PS4 №3)
# - вторые по количеству проданных игр
# 2. категория «Для всех от 10 лет и старше»
# - меньше всего игр в этой категории
# 3. категория «Подросткам»
# - самые низкие продажи
# - третьи в количестве проданных игр (в PS4 №1)
# 4. категория «Для взрослых»
# - первые по кол-ву проданных игр (в PS4 №2)
# - первые по объему продаж (в PS4 №1)
#
# **Диаграмма взаимных корреляций, по другим игровым платформам, данных по продажам и рейтингам критиков, пользователей и ESRB**

# %%
correlation = platform_top10_other.corr()
plt.figure(figsize=(12, 12))
sns.heatmap(correlation, vmax=1, square=True, annot=True, cmap='viridis')
plt.title('Диаграмма взаимных корреляций, данные по другим игровым платформам (кроме PS4)\n    ', fontsize=14);

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Тепловая карта с матрицей коореляции – это просто огонь 👍
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Обрати внимание, что наши действия повторяются с точки зрения построения графиков.
#
# Это говорит о том, что мы можем создать функцию, которая будет выполнять все действия за нас.
#
# Тем самым мы сможем оптимизировать свой код и проект целиком.
#
# </div>

# %% [markdown]
# ### Анализ диаграммы корреляций -- Другие платформы vs PS4:
#
# - Можно видеть, что остается высокое значение корреляции между общими продажами и продажами по Северной Америке, Европе и других странах = 0,89 - 0,93 ед., по Японии показатель незначительно снизился = 0,49 vs 0,53 ед.
# - Влияние отзывов критиков на продажи стало заметно меньше - 0,28 (в среднем) vs 0,41 ед. Все остальные рейтинги никак не влияют на продажи - значение корреляций очень мало.
# - Также в Японии влияние каких-либо рейтингов на продажи игр мало.
# - Отзывы критиков также мало влияют на оценки пользователей = 0,51 vs 0,53 ед.
# - Рейтинг ESRB не оказывает заметного влияния на другие показатели, что естественно потому что носит информативный характер в выборе игр.
#
# # Анализ прибильности игр по жанрам
# - Рассмотрим общее распределение игр по жанрам.
# - Определим самые прибыльные жанры
# - Определим жанры с высокими и низкими продажами

# %%
# Таблица распределения игр по жанрам

# подготовим таблицу
genre_sales = games.pivot_table(
    index=['genre'], values=['total_sales', 'name'], aggfunc={'total_sales':'sum', 'name':'count'})\

# переименуем столбцы
genre_sales.columns = ['name_count', 'total_sales']

#введем показатель продаж - сколько одна игра зарабатывает млн. долл.
genre_sales['share_sales'] = genre_sales.loc[:, 'total_sales'] / genre_sales.loc[:, 'name_count']

genre_sales = genre_sales.sort_values(by='total_sales', ascending=False)
genre_sales
# Out:
#               name_count  total_sales  share_sales
# genre
# Action              1031       441.12     0.427856
# Shooter              235       304.73     1.296723
# Role-Playing         370       192.80     0.521081
# Sports               268       181.07     0.675634
# Misc                 192        85.04     0.442917
# Platform              85        61.00     0.717647
# Racing               115        53.50     0.465217
# Fighting             109        44.49     0.408165
# Simulation            80        35.12     0.439000
# Adventure            302        29.43     0.097450
# Strategy              71        13.34     0.187887
# Puzzle                28         4.89     0.174643

# %% [markdown]
# Больше всего продаж в жанре "Action" - 441,2 млн. долл. Второе место у жанра "Shooter" - 304,73 млн. долл.
#
# **График количества проданных игр и глобальных продаж по жанрам**

# %%
ax=genre_sales[['name_count', 'total_sales']].plot(kind='bar', figsize=(10, 6))
plt.title('Количество проданных игр и глобальные продажи - распределение по жанрам\n  ', fontsize=14)
plt.ylabel('Количество игр, ед.')
plt.legend(['Количество проданных игр', 'Глобальные продажи'], loc='best')

# прозрачный второй график для создания правой y-оси
genre_sales[['total_sales']].plot(kind='bar', ax=ax, alpha = 0.0, legend=False, secondary_y=True)
plt.ylabel('Сумма, млн. долл.');

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# А если мы посмотрим на средние значения продаж, какие выводы мы сможем сделать ?
#
# Почему на средние значения ?
#
# Т.к. эта метрика более устойчива к выбросам, чем просто суммы и количественные показатели.
#
# И ведь мы этот показатель посчитали)
#
# </div>

# %% [markdown]
# ## Анализ распределения игр по жанрам
# - Первые по продажам игры в жанре "Action" - 441,2 млн. долл.
# Вторые - "Shooter".
# Самые плохопродаваемые игры в жанрах "Adventure", "Strategy", "Puzzle"
# - Игры жанра "Shooter" самые "дорогие" - показатель продаж Shooter ("share_sales") = 1,3 -- 1 игра = 1,3 млн. долларов.
# - У жанра "Sport" этот показатель почти в два раза меньше = 0,67 млн. долл - 1 игра.
# - Самые "дешевые" в этом плане Adventure = 0,09 млн. долл. - 1 игра.

# %% [markdown]
# # Шаг 3. Анализ пользователей из разных регионов

# %% [markdown]
# На данном этапе нам необходимо определить для пользователей из каждого региона:
#    - а. Самые популярные платформы (топ-5).
#    - б. Самые популярные жанры (топ-5).
#    - в. Влияние рейтиннга ESRB на продажи.
#
# **Самые популярные платформы (топ-5)**
#
# Для начала разберемся с 1 пунктом и подготовим данные по продажам игр по игровым платформам, в каждом регионе NA, EU, JP.

# %%
# данные по Северной Америке
platform_na_top5 = games.pivot_table(
    index=['platform'], values=['na_sales'], aggfunc='sum', margins=True, margins_name='All_sales') \
    .sort_values(by='na_sales', ascending=False).head(6)
display(platform_na_top5)
# таблица общих продаж по региону, с сумированием всех продаж, 
# с сортировкой по убыванию,
# вывод первых 6 строк (сумма продаж + топ-5 платформ) 

# данные по Европе
platform_eu_top5 = games.pivot_table(
    index=['platform'], values=['eu_sales'], aggfunc='sum', margins=True, margins_name='All_sales') \
    .sort_values(by='eu_sales', ascending=False).head(6)

display(platform_eu_top5)

# данные по Японии
platform_jp_top5 = games.pivot_table(
    index=['platform'], values=['jp_sales'], aggfunc='sum', margins=True, margins_name='All_sales') \
    .sort_values(by='jp_sales', ascending=False).head(6)

display(platform_jp_top5)
# Out:
#            na_sales
# platform
# All_sales    590.97
# X360         140.05
# PS4          108.74
# PS3          103.38
# XOne          93.12
# 3DS           55.31
#            eu_sales
# platform
# All_sales    506.82
# PS4          141.09
# PS3          106.86
# X360          74.52
# XOne          51.59
# 3DS           42.64
#            jp_sales
# platform
# All_sales    192.58
# 3DS           87.79
# PS3           35.29
# PSV           21.04
# PS4           15.96
# WiiU          13.01

# %%
platform_na_top5[1:6].plot(kind='bar', grid=True)
plt.title('ТОП-5 по продажам игровых платформ в Северной Америке\n  ')
plt.ylabel('Сумма, млн. долл')
plt.legend(loc='best');

platform_eu_top5[1:6].plot(kind='bar', grid=True)
plt.title('ТОП-5 по продажам игровых платформ в Европе\n  ')
plt.ylabel('Сумма, млн. долл')
plt.legend(loc='best');

platform_jp_top5[1:6].plot(kind='bar', grid=True)
plt.title('ТОП-5 по продажам игровых платформ в Японии\n  ')
plt.ylabel('Сумма, млн. долл')
plt.legend(loc='best');

# %% [markdown]
# ### Анализ продаж в регионах по платформам:
#
# 1. Первое место по продажам - Северная Америка = 591 млн. долл, затем Европа = 507 млн. долл., третье место - Япония = 192,6 млн. долл.
# 2. В Северной Америке и Европе набор ТОП-5 платформ один и тот же, разница только в распределении мест.
# 3. В Северной Америке на первом месте "родная" платформа X360, в Европе - PS4 (новый международный стандарт)
# 4. В Японии на первом месте (с большим отрывом в 2 раза) мобильная приставка 3DS - особенности менталитета и образа жизни японцев. Во первых Nintendo - родная торговая марка, на ней много контента "национального колорита", во вторых портативные приставки занимают меньше места в доме (тоже особенности Японии) и стоят дешевле.
# 5. Разница между первым и третим местом в Северной Америке = 40%, в Европе = 50%
#
# **Самые популярные жанры (топ-5)**
# Подготовим данные по продажам игр по жанрам, в каждом регионе NA, EU, JP

# %%
# данные по Северной Америке
genre_na_top5 = games.pivot_table(
    index=['genre'], values=['na_sales'], aggfunc='sum', margins=True, margins_name='All_sales') \
    .sort_values(by='na_sales', ascending=False).head(6)
display(genre_na_top5)
# таблица общих продаж по региону, с сумированием всех продаж, с сортировкой по убыванию,
# вывод первых 6 строк (сумма продаж + топ-5 жанров) 


# данные по Европе
genre_eu_top5 = games.pivot_table(
    index=['genre'], values=['eu_sales'], aggfunc='sum', margins=True, margins_name='All_sales') \
    .sort_values(by='eu_sales', ascending=False).head(6)

display(genre_eu_top5)


# данные по Японии
genre_jp_top5 = games.pivot_table(
    index=['genre'], values=['jp_sales'], aggfunc='sum', margins=True, margins_name='All_sales') \
    .sort_values(by='jp_sales', ascending=False).head(6)

display(genre_jp_top5)
# Out:
#               na_sales
# genre
# All_sales       590.97
# Action          177.84
# Shooter         144.77
# Sports           81.53
# Role-Playing     64.00
# Misc             38.19
#               eu_sales
# genre
# All_sales       506.82
# Action          159.34
# Shooter         113.47
# Sports           69.09
# Role-Playing     48.53
# Racing           27.29
#               jp_sales
# genre
# All_sales       192.58
# Role-Playing     65.44
# Action           52.80
# Misc             12.86
# Simulation       10.41
# Fighting          9.44

# %%
genre_na_top5[1:6].plot(kind='bar', grid=True)
plt.title('ТОП-5 по продажам в жанрах игр по Северной Америке\n  ')
plt.ylabel('Сумма, млн. долл')
plt.legend(loc='best'); 

genre_eu_top5[1:6].plot(kind='bar', grid=True)
plt.title('ТОП-5 по продажам в жанрах игр по Европе\n  ')
plt.ylabel('Сумма, млн. долл')
plt.legend(loc='best');


genre_jp_top5[1:6].plot(kind='bar', grid=True)
plt.title('ТОП-5 по продажам в жанрах по Японии\n  ')
plt.ylabel('Сумма, млн. долл')
plt.legend(loc='best');

# %% [markdown]
# ### Анализ продаж в регионах по жанрам:
#
# 1. Первое место по продажам - Северная Америка = 591 млн. долл, затем Европа = 507 млн. долл., третье место - Япония = 192,6 млн. долл.
# 2. В Северной Америке и Европе набор ТОП-5 жанров одинаков по составу и по распределению мест в топе (за исключением 5 места - несовпало).
#  -  1. Action    2. Shooter   3. Sports   4. Role-Playing      5.  Misc / Racing
# 3. В Японии свои предпочтения - на первом месте Role-Playing, далее два жанра - Action и Misc из первой пятерки других регионов и два последних Simulation и Fighting.
# 4. Распределение в долях между жанрами из ТОП-5 примерно одинаковое во всех регионах. За исключением Японии - тут 1 и 2 место идет со значительным отрывом от других жанров.
#
#
# **Влияние рейтинга ESRB на продажи в отдельном регионе**
# Этот вопрос мы уже выясняли выше. Построим диаграмму взаимных корреляций

# %%
correlation = platform_top10.corr()
plt.figure(figsize=(12, 12))
sns.heatmap(correlation, vmax=1, square=True, annot=True, cmap='viridis')
plt.title('Диаграмма взаимных корреляций, данные по всем игровым платформам ТОП-10 продаж\n    ', fontsize=14);

# %% [markdown]
# Мы предварительно обозначили рейтинг ESRB в числах. По диаграмме взаимных корреляций видно что даже по ТОП-10 платформ по продажам игр влияние рейтнга ESRB (rating_num в таблице) на продажи игр по всем регионам ОТСУТСТВУЕТ. Значение коэф. корреляций практически равны нулю.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Достаточно детально проанализировали наши данные и изучили портреты пользователей.
#
#
#
# Давай теперь проверим наши гипотезы.
#
# </div>

# %% [markdown]
# # Шаг 4. Проверка гипотез
# На данном этапе нам необходимо проверить следующие гипотезы:
# 1. Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# 2. Средние пользовательские рейтинги жанров Action (англ. «действие», экшенигры) и Sports (англ. «спортивные соревнования») разные.
#
# **Гипотеза 1** - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
# Проверим эту гипотезу с помощью одностороннего теста, т.е мы найдем одно из значений среднего пользовательского рейтинга и сравним его с другим через t-test
#
# Гипотезу будем провериять двумя вариантами
#
# 1 - без замены NaN значений на средние значения по признаку
# 2 - заменим NaN на средние значения по признаку
# Исходя из формулировки гипотезы принимаем **нулевую гипотезу H₀ как:
# Средние пользовательские рейтинги платформ Xbox One равны средним пользовательским рейтингам платформы PC.**
#
# **Альтернативная гипотеза звучит так: Средние пользовательские рейтинги платформ Xbox One и PC различаются.**
#
# Уровень значимости (пороговое значение) установим как 5% (как общепринятый параметр)
#
# Найдем среднее значение пользовательского рейтинга платформы РС

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Гипотезы сформулированы верно.
#
#
# **Best practies:**
#
# Перед проверкой гипотезы рекомендую проверить дисперсии выборок, чтобы корректно определить атрибут `equal_val` в Т–тесте.
#
# В том числе стоит визуализировать распределение каждой выборки, чтобы определить нормальное ли у них распределение или нет.
#
# Так мы покажем логичность и последовательность наших действий.
#
# </div>

# %%
games.info()
#В данных по пользовательскому рейтингу есть пропущенный значения
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2886 entries, 0 to 2885
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             2886 non-null   object
#  1   platform         2886 non-null   object
#  2   year_of_release  2886 non-null   int64
#  3   genre            2886 non-null   object
#  4   na_sales         2886 non-null   float64
#  5   eu_sales         2886 non-null   float64
#  6   jp_sales         2886 non-null   float64
#  7   other_sales      2886 non-null   float64
#  8   critic_score     1312 non-null   float64
#  9   user_score       1531 non-null   float64
#  10  rating           1611 non-null   object
#  11  rating_num       1611 non-null   float64
#  12  total_sales      2886 non-null   float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 293.2+ KB

# %% [markdown]
# Проверка Гипотезы 1 - Вариант 1 (без замены NaN на среднее значение)
#
# Найдем среднее значение пользовательского рейтинга по игровой платформе PC

# %%
mean_pc = games.loc[games['platform']
                          == 'PC', 'user_score'].mean(skipna=True) # среднее и без параметра "пропуск NaN" также считает.
"Значение среднего пользвательского рейтинга по платформе РС = {:.3} это наша оптимальная величина" \
    .format(mean_pc)
# Создадим таблицу данных по пользовательскому рейтингу платформы Xbox One

games.platform.unique()  # правильные названия всех платформ
# Out:
# array(['PS3', 'X360', 'PS4', '3DS', 'DS', 'XOne', 'WiiU', 'Wii', 'PC',
#        'PSV', 'PSP'], dtype=object)

# %%
x_one_user_score = games.loc[games['platform'] == 'XOne', 'user_score']
x_one_user_score.head()  # проверка
# Out:
# 21    NaN
# 31    7.9
# 34    5.4
# 44    6.4
# 53    6.2
# Name: user_score, dtype: float64

# %% [markdown]
# **Расчитаем значение p и проверим нулевую гипотезу с помощью одностороннего теста**

# %%
optimal_value = mean_pc
alpha = 0.05            # уровень статистической значимости

results = st.ttest_1samp(x_one_user_score, optimal_value,
                         nan_policy='omit')                # не учитываем NAN
print('p-значение: ', results.pvalue)

# сравним получившееся p-значение с заданным уровнем статистической значимости
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  0.3658943556927369
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера: ❗️</b>
#
# В конструкции `if`можно писать условие без скобок. Для логики это неважно, но чем меньше символов в коде — тем легче его читать. Чтобы продемонстрировать коллегам хороший стиль кода, привыкай писать условия без скобок.
#
# </div>

# %% [markdown]
# **Нет подтверждения того, что гипотеза не верна. Мы не можем уверено утверждать как соотносятся два средних пользовательских рейтинга платформ Xbox One и PC - одинаковы они или нет**
#
# Проверка Гипотезы 1 - Вариант 2 (заменим NаN на среднее значение пользовательского рейтинга по платформе Xbox One)

# %%
# расчитаем среднее значение рейтинга по платформе Xbox One
x_one_user_score_mean = games.loc[games['platform'] == 'XOne', 'user_score'].mean()
x_one_user_score_mean
# заменим NaN на среднее значение рейтинга по платформе Xbox One
x_one_user_score.fillna(x_one_user_score_mean, inplace=True)
x_one_user_score
# Out:
# 21      6.521429
# 31      7.900000
# 34      5.400000
# 44      6.400000
# 53      6.200000
#           ...
# 2854    8.200000
# 2858    6.600000
# 2860    6.521429
# 2867    6.700000
# 2871    6.521429
# Name: user_score, Length: 247, dtype: float64

# %%
# Расчитаем значение p и проверим нулевую гипотезу с помощью одностороннего теста

optimal_value = mean_pc
alpha = 0.05             # уровень статистической значимости 

results = st.ttest_1samp(x_one_user_score, optimal_value)
print('p-значение: ', results.pvalue)

# сравним получившееся p-значение с заданным уровнем статистической значимости
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  0.21946193049280835
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# **Нет подтверждения того, что гипотеза не верна. Мы не можем уверено утверждать как соотносятся два средних пользовательских рейтинга платформ Xbox One и PC - одинаковы они или нет**
#
#
# **Гипотеза 2** - Средние пользовательские рейтинги жанров Action и Sports разные.
#
# Нулевая гипотеза: Средние пользовательские рейтинги жанров Action и Sports *одинаковые*.
#
# Альтернативная гипотеза: Средние пользовательские рейтинги жанров Action и Sports *разные*.
# Проверим эту гипотезу метода проверки равенства средних двух генеральных совокупностей
#
# Гипотезу будем провериять двумя вариантами
#
# - 1 - без замены NaN значений на средние значения по признаку
# - 2 - заменим NaN на средние значения по признаку
# Исходя из формулировки гипотезы принимаем нулевую гипотезу H₀ как:
# Средние пользовательские рейтинги жанров Action и Sports одинаковы
#
# Уровень значимости (пороговое значение) установим как 1% (вероятность возможного подтверждения H₀ очень мала)
#
# Проверка Гипотезы 2 - Вариант 1 (без замены NaN на среднее значение)
#
# Подготовим данные

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Гипотезы сформулированы верно.
#
#
#
# </div>

# %%
# данные по жанру Action
action_user_score = games.loc[games['genre'] == 'Action', 'user_score']

# данные по жанру Sport
sports_user_score = games.loc[games['genre'] == 'Sports', 'user_score']

# %%
# Расчитаем значение p и проверим нулевую гипотезу

alpha = 0.01  # уровень статистической значимости

results = st.ttest_ind(action_user_score, sports_user_score,
                       equal_var=False, nan_policy='omit')    # не учитываем NaN
print('p-значение:', results.pvalue)

# сравним получившееся p-значение с заданным уровнем статистической значимости
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 4.24307776572644e-20
# Отвергаем нулевую гипотезу

# %% [markdown]
# **Гипотеза верна - Средние пользовательские рейтинги жанров Action и Sports разные.**
#
# **Проверка Гипотезы 2 - Вариант 2 (заменим NаN на средние значения пользовательского рейтинга по жанрам Action и Sports)**
#
# Подготовим данные

# %%
# расчитаем среднее значение пользовательского рейтинга по жанру Action
action_user_score_mean = games.loc[games['genre'] == 'Action', 'user_score'].mean(skipna=True)

# заменим NaN на среднее по рейтингу
action_user_score.fillna(action_user_score_mean, inplace=True)

# расчитаем среднее значение пользовательского рейтинга по жанру Sport
sports_user_score_mean = games.loc[games['genre'] == 'Sports', 'user_score'].mean(skipna=True)

# заменим NaN на среднее по рейтингу
sports_user_score.fillna(sports_user_score_mean, inplace=True)
sports_user_score
# Out:
# 14      4.300000
# 19      5.000000
# 26      4.300000
# 28      5.700000
# 52      4.500000
#           ...
# 2781    5.455897
# 2785    4.500000
# 2811    1.400000
# 2857    5.455897
# 2858    6.600000
# Name: user_score, Length: 268, dtype: float64

# %%
# Расчитаем значение p и проверим нулевую гипотезу

alpha = 0.01  # уровень статистической значимости

results = st.ttest_ind(action_user_score, sports_user_score, equal_var=False)
print('p-значение:', results.pvalue)

# сравним получившееся p-значение с заданным уровнем статистической значимости
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 1.4717911522140826e-36
# Отвергаем нулевую гипотезу

# %% [markdown]
# Исход тот же. **Гипотеза верна - Средние пользовательские рейтинги жанров Action и Sports разные.**
#
# Только p-значение стало еще меньше. Не факт что это правильный(нужный) подход замены NAN значений.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Обрати внимание, что наши действия также повторяются с точки зрения расчетов статистических тестов, это говорит о том, что мы можем также создать здесь функцию 😊
#
# </div>

# %% [markdown]
# # Шаг 5. Заключение
#
# **Данные для проведения исследования**
# - Часть данных потребовалось перевести в нижний регистр написания букв - названия столбцов, название игр(чтобы исключить пропуск дубликатов)
# - Обнаружены пропуски - по значениям рейтингов от 40 до 50% от всех данных, по названиям игр и жанров - 0,01%, по году выпуска игр - 1,61%
# - По столбцу Year_of_Release нужно было заменить тип данных на datatime.
# - По столбцам рейтингов нужно было заменить типы данных на числовые, по возможности на целочисленные.
#
# **Итог проведенной предобработки данных**
# - Названия столбцов и игр перевели в нижний регистр.
# - Проверили и удалили пропуски по названию игры и жанру - 2 записи.
# - Проверили и удалили пропуски по признаку "год выпуска". В части записей - год релиза восстановили по названию игры.
# - Провели оценку возможности замены пропущенных значений в рейтингах - решили замену отсутствующих значений не проводить, без необходимости связанной с вычислениями и анализом данных в соответствующих заданиях.
# - Данные "год выпуска" перевели в формат "int64"
# - Значений "TBD" обнаруженные в рейтинге, заменили на NaN в соответствии со смыслом выражения "TBD" - рейтинг должен быть определен.
# - Оптимизировали данные по рейтингу ESRB, руководствуясь официальной информацией и терминологией ESRB - количество категорий сократили до 4.
# - Создали числовой аналог столбца рейтинга ESRB для возможности внести этот рейтинг в анализ корреляции.
# - Проверили базу на наличие дубликатов - дубликатов нет. Предварительно проверили названия игр, жанров, платформ, на уникальность во избежании пропуска дубликатов.
# - Провели переиндексацию данных.
#
# **Анализ данных**
# - В базе представлена информация по выходу игр с 1980 по 2016 гг. Первые 10-12 лет количество игр не превышало 100 ед. Рост продаж начался с 1994-1995 гг. (около 200 ед.). Пик продаж пришелся на 2008-2009 гг.(1425 ед.) После этого периода продажи игр стабильно снижаются. С точки зрения продаж интересен период с 1997 по 2016 гг. в том числе из-за наличия внятного числа рейтингов появившихся в этот период.
#
# **Продажи игр по платформам.**
# - ТОП-6 платформ по продажам за весь период наблюдений - PS2, X360, PS3, Wii, DS, PS.
# - Объем продаж по этим платформам от 1200 до 700 млн. долл.
# - Характерный "срок жизни" более менее успешных платформ - 10 лет(+/-2 года)
# - Определили актуальный период до 5 лет - с 2012 по 2016 гг. (включительно). Если рассматривать тот факт что срок жизни платформ - 10 лет, то если брать период последние 5 лет, в него попадут платформы которые все еще активны на рынке.
#
# **Анализ нескольких потенциально прибыльных платформ**
# - Самыми успешными по продажам в эти 5 лет были Х360, PS3, PS4, XOne и Wii. По этим данным провели анализ продаж. В период 2012-2016 гг. по всем платформам снижается глобальная выручка в том числе в ТОР10 платформ.Медианные значения у этой группы выше чем у остальных - значит снижение продаж было либо позже чем у остальных, либо не таким резким было падение.
# - Выбрали для анализа PS4 как лидера по глобальным продажам.
# - Северная Америка, Европа и другие страны вносят заметный вклад в глобальные продажи игр на PS4 - высокое значение корреляции = 0,93 - 0,96. У Японии этот показатель меньше = 0,53, т.е. влияние Японии на глобальные продажи мало.
# - Связь между объемами продаж и отзывами критиков и пользователей есть (но слабо выраженное) - лучше продаются те игры на которые больше положительных отзывов. По всем регионам (кроме Японии) и по общим продажам - в пределах 0,35-0,42 ед. корреляции. В Японии влияние каких-либо рейтингов на продажи игр ничтожно мало.
# - Отзывы критиков действительно не сильно влияют на оценки пользователей - тут коэф. корреляции = 0,56.
# - В основном оценки критиков и пользователей выше среднего, примерно 3/4 от максимума
# - Встречаются высокие единичные оценки на игры которые плохо продаются.
# - Рейтинг ESRB не оказывает заметного влияния на другие показатели.
#
# **Влияние на продажи игр отзывов пользователей и критиков по другим игровым платформам**
# - Также продажи по Северной Америке, Европе и других странах это важные величины для глобальных продаж других платформ, коэф. корреляции = 0,89 - 0,95 ед., по Японии показатель стал ниже = 0,49 vs 0,53 ед.
# - Влияние отзывов критиков на продажи стало заметно меньше - 0,28 (в среднем) vs 0,41 ед. Все остальные рейтинги никак не влияют на продажи - значение корреляций ничтожно мало. Естественная тенденция сохраняется - лучше продаются те игры на которые больше положительных отзывов. Есть часть малопродаваемых игр с положительными отзывами.
# - Также в Японии влияние каких-либо рейтингов на продажи игр ничтожно мало.
# - Отзывы критиков также мало влияют на оценки пользователей = 0,51 vs 0,53 ед.
# - Основные отзывы критиков и пользователей это показатели оценок выше среднего и до 3/4 от максимума.
# - Встречаются высокие единичные оценки на игры которые плохо продаются.
# - Рейтинг ESRB не оказывает заметного влияния на другие показатели.
#
# **Анализ прибильности игр по жанрам**
# - Первые по продажам игры в жанре "Action" - 441,2 млн. долл.
# - Вторые - "Shooter".
# - Самые плохопродаваемые игры в жанрах "Adventure", "Strategy", "Puzzle"
# - Игры жанра "Shooter" самые "дорогие" - показатель продаж Shooter ("share_sales") = 1,3 -- 1 игра = 1,3 млн. долларов.
# - У жанра "Sport" этот показатель почти в два раза меньше = 0,67 млн. долл - 1 игра.
# - Самые "дешевые" в этом плане "Adventure" = 0,09 млн. долл. - 1 игра.
#
# **Портрет пользователя каждого региона**
# - Определили для пользователя каждого региона (NA, EU, JP):
#     -- Самые популярные платформы (топ-5)
#     -- Первое место - Северная Америка = 591 млн. долл., затем Европа = 507 млн. долл., 3 место - Япония = 192,6 млн. долл.
#     -- В Северной Америке и Европе набор ТОП-5 платформ один и тот же, разница только в распределении мест.
#   X360 - PS4 - PS3 - XOne - 3DS
#     -- В Северной Америке на первом месте "родная" платформа X360, в Европе - PS4 (новый международный стандарт)
#     -- В Японии на первом месте (с большим отрывом в 2 раза) мобильная приставка 3DS - особенности менталитета и образа жизни японцев.
#     -- Разница между первым и третим местом в Северной Америке = 40%, в Европе = 50%
#
# **Самые популярные жанры (топ-5)**
# - В Северной Америке и Европе набор ТОП-5 жанров одинаков по составу и по распределению мест в топе (за исключением 5 места - несовпало).
# Action 2. Shooter 3. Sports 4. Role-Playing 5. Misc / Racing
# - В Японии свои предпочтения - на первом месте Role-Playing, далее два жанра - Action и Misc из первой пятерки других регионов и два последних Simulation и Fighting.
# - Распределение в долях между жанрами из ТОП-5 примерно одинаковое во всех регионах. За исключением Японии - тут 1 и 2 место идет со значительным отрывом от других жанров.
# - Влияние рейтинга ESRB на продажи в отдельном регионе Проанализировали данные по методу взаимных коррреляций признаков. Анализ покащал что влияние рейтнга ESRB на продажи игр по всем регионам ОТСУТСТВУЕТ. Значение коэф. корреляций практически равны нулю.
#
# **Проверка гипотез**
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#       - Проверили гипотезу с помощью одностороннего теста. Исходя из формулировки приняли нулевую гипотезу H₀ как: Средние пользовательские рейтинги платформ Xbox One равны средним пользовательским рейтингам платформы PC. Уровень значимости установили как 5%(общепринятый параметр)
#       - Сделали два варианта расчетов: 1 - без замены NaN на средние значения по признаку, 2 - заменили NaN на средние значения по признаку.
#       - Итог - Нет подтверждения того, что гипотеза не верна. Мы не можем уверено утверждать как соотносятся два средних пользовательских рейтинга платформ Xbox One и PC - одинаковы они или нет.
# - Средние пользовательские рейтинги жанров Action и Sports разные
#     - Проверили гипотезу методом проверки равенства средних двух генеральных совокупностей. Исходя из формулировки гипотезы приняли нулевую гипотезу H₀ как: Средние пользовательские рейтинги жанров Action и Sports одинаковы. Уровень значимости установили как 1% (вероятность возможного подтверждения H₀ очень мала). Сделали два варианта расчетов: 1 - без замены NaN на средние значения по признаку, 2 - заменили NaN на средние значения по признаку.
#     - Итог - Гипотеза верна - Средние пользовательские рейтинги жанров Action и Sports разные.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# В целом сам проект выполнен на хорошем уровне! На протяжении всей работы чувствуется глубина проработки задачи и это безусловный плюс для нас. Было использовано большое количество методов, которые будут помогать тебе в дальнейших проектах.
#
#
#
# **[общий комментарий]** Ячейки **markdown** в том числе мы можем использовать как дополнительный способ стилизации нашего проекта. Оставил ниже ссылку, с примерами стилизации.
#
# https://sqlbak.com/blog/jupyter-notebook-markdown-cheatsheet
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
#
# Возвращаю проект обратно, чтобы убедиться что все мои комментарии понятны.
#
# Если вдруг у тебя возникнут какие-то вопросы, то я с радостью отвечу на них 😊
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера (2): ✅</b>
#
# Рад, что в целом все понятно. Тогда предлагаю двигаться дальше.
#
# Поздравляю с успешным завершением проекта 😊👍
#
# И желаю успехов в новых работах 😊
#
#
# </div>
