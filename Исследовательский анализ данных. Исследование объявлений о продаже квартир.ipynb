# %% [markdown]
# <span style="color:blue">**Привет еще раз!**</span>
#
# Спасибо, что доработала проект, критические замечания исправлены. Поздравляю, твой проект принят! Надеюсь мое ревью было полезным. Желаю успехов в учебе и со следующими проектами!
#
# Оформление комментариев оставим таким же, только обозначим номер проверки.
#
# <span style="color:purple">**Привет, Евгения!**</span>
#
# Меня зовут **Василий Удинкан** и я - ревьювер, буду проверять твой проект. Ты проделала большую работу над проектом, но давай сделаем его еще лучше.
#
# Если не против, я буду обращаться к тебе на "ТЫ". Если это неприемлемо, обязательно напиши мне в комментариях – мы прейдем на "ВЫ".
#
# Спасибо, что сдала проект. В тетради ты сможешь найти мои комментарии. Пострайся учесть эти комментарии в ходе выполнения дальнейших проектов.
#
# Твой проект обладает хорошей структурой и понятной логикой исследования. Тем не менее, в нём обнаружились недочёты, которые необходимо будет исправить.
#
# Обрати внимание, я буду выделять свои комментарии цветом, в зависимости от того, какие действия, важность и особенности тебя ждут в процессе проверки.
#
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Такими комментариями я буду помечать хорошо проделаную работу, а так же хорошо проделаную работу над ошибками.
# </div>
#
# <div class="alert alert-block alert-warning">
#
# **Комментарий ревьювера (что можно улучшить)**
#
# После таких комментариев ничего исправлять не нужно, но я дам рекомендации на будущее и подскажу, что можно улучшить.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# **Комментарий ревьювера (недочет, который нужно доработать)**
#
# Если ты видишь такой комментарий, значит я указываю тебе на недочёт, его нужно исправить. Без такого исправления я не приму твою работу:)
# </div>
#
# **Пожалуста, не удаляй мои комментарии. При повторной проверке, я буду ориентироваться на них.**
#
# <span style="color:blue"> Можешь под моими комментариями оставлять свои, в которых опиши свои испарвления. Это облегчит процесс проверки и мне, и тебе:) Например, вот так:</span>
#
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: </b>
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Комментарий ревьювера (что можно улучшить)**
#
# Небольшая вводная перед исследованием даст быстрое понимание о том, чему оно посвящено. Здорово, что обращаешь на это внимание. Но я бы порекомендовал в будущих проектах добавить цели и задачи и оформить введение. Например:
#
# ____
#
# **Название проекта**
# _____
# **Описание исследования.**
#
# _____
# **Цель исследования.**
#
# Суть исследования. Например:
#
# Провести анализ данных при помощи которых предприятие разработает стратегию взаимодействия с клиентами.
#
# _____
# **Задачи исследования.**
#
# Действия, необходимые для достижения поставленной цели.
# _____
# **Исходные данные.**
#
# Здесь описываешь исходные таблицы.
# ______
#
# **Данное исследование разделим на несколько частей.**
#
# Твое содержание.
# _________________
#
# **Почему это важно?** Когда ты будешь в будущем выполнять тестовые задания, просто скопировав присланную тебе задачу и не составив плана, ты можешь смутить будущего работодателя. А грамотно сконфигурированный план покажет тебя как ответсвенного и усидчивого специалиста. Также такой подход научит тебя структурировать исследование и не путаться при работе с большими проектами.
# </div>

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
display(data.head())
display (data.tail())
display(data.sample(10))
data.info()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Импортировав несколько библиотек, которые помогут нам в дальнейшем проекте, мы прочитали файл, но в изначальном виде у него не было разделителей, соотвественно данные были распределены в одной колонке, поэтому мы использовали sep='\t', чтобы сами данные выглядели правильно.
#
# После того, как просмотрели таблицу, увидели, что в ней есть недостающие значени, с ними надо будет разбираться, потому что где-то эти недостающие значения могут являться правдивыми, а где-то ошибкой в данных. Также метод info показал, что в некоторых столбцах стоит изменить тип данных, со всем этим будем разбираться в "Предобработке данных".

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Проблемы в данных были выявлены.
#
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Стоит начать разбираться с тем, что сразу бросилось в глаза:
#
# 1. В столбце "first_day_exposition" необходимо привести данные к формату год-месяц-день, чтобы было удобнее разбираться. Кроме того, почему же все данные имеют время 0 часов и 0 минут?
# 2. Проверить названия из столбца "locality_name" на уникальность и заменить букву "ё" на букву "е".
# 3. Проверить все нулевые значения и посмотрим что из них можно заменить на 0.

# %%
# выполняем пункт №1
data['first_day_exposition'] = pd.to_datetime(
    data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
data['first_day_exposition'] = data['first_day_exposition'].dt.round(
    '1D')  # округлить до 1 дня
data.head()

# теперь данные в этом столбце выглядет намного приятнее и с ними будет удобнее работать.
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Все супер, даты приведены в рабочий вид.
#
# </div>

# %%
# выполняем пункт №2
data['locality_name'].unique() #очень сложно было разобраться в таком количестве значений, но все-же повторяющееся значение имеется (посёлок и поселок)
# на всякий случай еще использовала метод counter, но с помощью него ничего нового не было обнаружено
# from collections import Counter
# Counter(data['locality_name'])
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %%
# меняем ё на е, чтобы было убодно работать с данными и они не повторялись 
data['locality_name'] = data['locality_name'].str.replace('ё', 'е')
data['locality_name'].unique()  # проверка
# Out:
# array(['Санкт-Петербург', 'поселок Шушары', 'городской поселок Янино-1',
#        'поселок Парголово', 'поселок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина',
#        'деревня Федоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'поселок Металлострой',
#        'поселок городского типа Лебяжье',
#        'поселок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'поселок Аннино',
#        'поселок городского типа Ефимовский', 'поселок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
#        'Красное Село', 'поселок Понтонный', 'Сясьстрой', 'деревня Старая',
# ...

# %%
# дело дошло до пункта #3. Изначально стоит узнать, сколько же и в каких столбцах у нас вообще имеются пропуски. 
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Комментарий ревьювера (что можно улучшить)**
#
# Не путай нулевые значения с пустыми:) Это разные определения.
# </div>

# %% [markdown]
# Исходя из полученных данных будем проверять следующие занчения:
# а. ceiling_height (высота потолков) нулевого значения не может быть, но можем ее заменить на медианное значение.
# б. floors_total в 86 записях отсутствует значение общего количества этажей - проверяем.
# в. living_area (Общая площадь квартиры) отсутствует в 1903 записях - много, исключение этих данных может сильно повлиять на выводы.
# г. Значение is_apartment (аппартаменты) имеет аж 20924 пропуска, будем изучать и приводить в булевый формат.
# д. kitchen_area (площадь кухни) имеет 2278 пропусков, мы заменим NaN на 0.
# е. balcony (балконы) - отсутствие данных о балконах можем считать как отсутсвием балкона - заменяем на 0
# ё. locality_name (названия местоположение квартир) - явная ошибка - таких 49. Изучим - возможно без этих объявлений данные не сильно пострадают.
# ж. airports_nearest, cityCenters_nearest, parks_around3000,parks_nearest (все ээти данны рассказывают нам, какое расстояние от квартиры до какого-либо объекта). Скорее всего это ошибка заполнения анкет, но заполнить их нереально. С этим вопросом необходимо обращаться к сборщикам данных.
# з. days_exposition (кол-во дней публикации). Мы не знаем закрыта ли публикация или нет, но изменить этот параметр на какой-либо другой можно.
# и. мне не нравятся значение комнат = 0. Ошибка ли это?
# Поэтому нам необходимо изменить данные в следующих столбцах:
# 0. ceiling_height +
# 1. floors_total +
# 2. living_area and kitchen_area +
# 3. is_apartment +
# 4. balcony +
# 5. locality_name +
# 6. days_exposition +
# 7. переименовка столбца cityCenters_nearest + изменение данных до центра
# 8. rooms +

# %%
# начнем с удаления данных с незначительным количеством пропусков: 
data.dropna(subset=['locality_name', 'floors_total'], inplace=True)

#Проделаем то же самое с balcony, где видимо 0 балконов = Nan
data['balcony'].fillna(0, inplace=True)

#Разберемся со столбцом is_apartment. Почему так много пропусков и какие вообще там есть значения?
data['is_apartment'].unique()
#Значения nan, False и True. Заменим nan на False:
data['is_apartment'].fillna(False, inplace=True)
# переименовка столбца cityCenters_nearest
data.rename(columns = {'cityCenters_nearest':'citycenters_nearest'}, inplace=True)
#Nan в ceiling_height заменим медианными значениями
data['ceiling_height'].fillna(data['ceiling_height'].median(), inplace=True)

data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1865
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2222
# balcony                     0
# locality_name               0
# airports_nearest         5524
# citycenters_nearest      5501
# parks_around3000         5500
# parks_nearest           15535
# ponds_around3000         5500
# ponds_nearest           14529
# days_exposition          3171
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Комментарий ревьювера (что можно улучшить)**
#
# Главное не забыть отфильтровать нулевые значения в days_exposition при анализе, так как эти нули повлияют на расчеты.
#
# В целом можно не заполнять пропуски 0 в days_exposition. Вполне вероятно, что эти объявления не были сняты. Проверить это можно при помощи графика, отображающий пустые значения по годам. Больше всего пропусков будет для объявлений последних лет.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: </b>
#     Точно, не подумала изначально к каим последствиям это может превести. Решила вообще не трогать этот столбец и разобраться с ним потом)
# </div>

# %%
print('Количество NaN по days_exposition:', data['days_exposition'].isnull().sum())
# Out:
# Количество NaN по days_exposition: 3171

# %%
# Проверим количество комнат по вариантам (либо это студия, либо очень маленькая квартира, либо ошибка) 1 вариант:
zero_flats_data = data.query('rooms == 0')
# display(zero_flats_data['studio'])
#Далеко не все квартиры с 0 комнат - студии. Но может это просто маленькие квартиры?
# display(zero_flats_data['total_area'].unique())
#В большинстве своем это действительно так, кроме пары исключений.
#Сделаем так: если площадь больше 50 кв. и это не студия, то удалим такие значения, но сначала проверим сколько их
# display(zero_flats_data.query('total_area > 50 & studio==False'))
 
#Такое значение всего одно! Возможно это ОЧЕНЬ большая студия. Оставим, как есть.
#Все остальные квартиры с 0 комнат и не студии - просто маленькие.
#Взглянем на них поподробнее еще раз:
# print(data.query('rooms == 0 & studio==False'))
 
#У всех квартир с 0 комнат и не-студий указана living_area. В общем, хотя бы 1 комната там есть.
#Так что поменяем 0 на 1 и не будем путаться
 
data.loc[(data['rooms'] == 0) & (data['studio']==False), 'rooms'] == 1
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00           2019-03-07      3
# 1             7   3350000.0       40.40           2018-12-04      1
# 2            10   5196000.0       56.00           2015-08-20      2
# 3             0  64900000.0      159.00           2015-07-24      3
# 4             2  10000000.0      100.00           2018-06-19      2
# 5            10   2890000.0       30.40           2018-09-10      1
# 6             6   3700000.0       37.30           2017-11-02      1
# 7             5   7915000.0       71.60           2019-04-18      2
# 8            20   2900000.0       33.16           2018-05-23      1
# 9            18   5400000.0       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0        51.00      8         False  ...
# 1            2.65          11.0        18.60      1         False  ...
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Согласен с решением.
#
# </div>

# %%
# Пропуски жилой площади заменю на отношение средней жилой площади к жилой площади по строке
data.plot(x='living_area', y='total_area', kind='scatter', grid=True) 
plt.text(190, 150, 'коэффициент корреляции: ' + str(round(data['living_area'].corr(data['total_area']), 2)))
plt.title("Отношение средней жилой площади к общей площади")
plt.ylabel("Общая")
plt.xlabel("Жилая")
# Out:
# Text(0.5, 0, 'Жилая')

# %%
# По диаграмме рассеивания, и коэффициенту корреляции прослеживается линейность отношение общей площади к жилой площади

mean_living_area = (data['living_area'] / data['total_area']).mean()
data['living_area'] = data['living_area'].fillna(round((data['total_area'] *mean_living_area), 1))
data['living_area'].isna().value_counts()
# Out:
# False    23565
# Name: living_area, dtype: int64

# %%
# Пропуски площади кухни так же заменю на отношение средней площади кухни к жилой площади по строке.
data.plot(x='kitchen_area', y='total_area', kind='scatter', grid=True) 
plt.text(55, 20, 'коэффициент корреляции: ' + str(round(data['kitchen_area'].corr(data['total_area']), 2)))
plt.title("Отношение площали кухни к общей площади")
plt.ylabel("Общая")
plt.xlabel("Кухня")
mean_kitchen_area = (data['kitchen_area'] / data['total_area']).mean()
data['kitchen_area'] = data['kitchen_area'].fillna(round((data['total_area'] *mean_kitchen_area), 1))
data['kitchen_area'].isna().value_counts()
# Заменим значения площади кухни в квартирах-студиях на нули
data.loc[data['studio'] == True, 'kitchen_area'] = 0
data.loc[data['studio'] == True]
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5524
# citycenters_nearest      5501
# parks_around3000         5500
# parks_nearest           15535
# ponds_around3000         5500
# ponds_nearest           14529
# days_exposition          3171
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Согласен с решением, здорово, что определила зависимости перед восстановлением данных.
#
# </div>

# %%
# Проверю на ошибки ввода площади, есть ли квартиры где сумма жилой площади и кухни больше общей

data.query('total_area < (living_area+kitchen_area)')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 184               7   2600000.0       30.20           2018-02-14      1
# 424              14  11500000.0       98.00           2016-05-10      3
# 545               9   4700000.0       23.80           2018-12-28      1
# 551               8   3100000.0       31.59           2018-03-08      1
# 601              12   5600000.0       53.70           2017-04-18      2
# ...             ...         ...         ...                  ...    ...
# 22095             6   2194000.0       36.50           2017-09-27      1
# 22907             9  65000000.0      228.00           2016-06-02      4
# 23102             0   5800000.0       66.00           2017-06-09      5
# 23191             3   1900000.0       18.90           2016-04-04      1
# 23202            13   4919880.0       67.92           2018-10-23      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
#Сумма жилой площади и кухни больше общей, ошибки ввода данных. Удалю строки с ошибками

data = data.query('total_area > (living_area+kitchen_area)')
data.query('total_area < (living_area+kitchen_area)')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, citycenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
# Разберемся с расстоянием до центра непосредственно в городе Санкт-Петербурге
data[(data['locality_name'] == 'Санкт-Петербург') & (data['citycenters_nearest'].isna())]
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 81                9   10949000.0       68.00           2018-12-27      1
# 593              20    4200000.0       38.30           2019-04-16      1
# 604              11    9899000.0      101.00           2018-12-12      3
# 742               7   37000000.0      161.00           2016-05-22      3
# 795              19    7100000.0       59.60           2019-02-13      2
# 1336             12   18500000.0       66.00           2017-06-08      1
# 1872             13    3100000.0       32.00           2019-03-15      1
# 1895             12    9500000.0      130.00           2019-03-27      5
# 2364             17    4300000.0       32.60           2019-04-28      1
# 2707             14    5650000.0       51.00           2019-02-26      2
# 2882              6   28099500.0      174.00           2018-12-19      3
# 3200              9   10912400.0       68.00           2018-12-19      1
# ...

# %%
# параметр расстояния до центра города важен только в Санкт-Петербурге. 
#Поэтому квартиры без расстояния до центра в Санкт Петербурге будем дропать).
data = data[(data['locality_name'] != 'Санкт-Петербург') 
            | ((data['locality_name'] == 'Санкт-Петербург') 
               & (~data['citycenters_nearest'].isna()))].reset_index(drop=True)
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5402
# citycenters_nearest      5379
# parks_around3000         5378
# parks_nearest           15353
# ponds_around3000         5378
# ponds_nearest           14344
# days_exposition          3112
# dtype: int64

# %%
 # Остальные данные просто заменяем на 0, так как нет возможности их заполнить верно, а отсутсвует слишком много инфоормации.
data['parks_around3000'] = data['parks_around3000'].fillna(0)
data['ponds_around3000'] = data['ponds_around3000'].fillna(0)
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5402
# citycenters_nearest      5379
# parks_around3000            0
# parks_nearest           15353
# ponds_around3000            0
# ponds_nearest           14344
# days_exposition          3112
# dtype: int64

# %%
# Оптимизируем данные по регистру и целочисленному значению. (нам не требуется информация до сантиметров)
data['floors_total'] = data['floors_total'].astype('int')#  этажи
data['last_price'] = data['last_price'].astype('int') # Цена без копеек
data['balcony'] = data['balcony'].astype('int') # балкон
data['parks_around3000'] = data['parks_around3000'].astype('int') # Точность до метра
data['ponds_around3000'] = data['ponds_around3000'].astype('int') # Точность до метра
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65             5         34.3      4         False  ...
# 3            2.65            14         89.8      9         False  ...
# 4            3.03            14         32.0     13         False  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0        0  Санкт-Петербург           18863.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23325 entries, 0 to 23324
# Data columns (total 22 columns):
# total_images            23325 non-null int64
# last_price              23325 non-null int64
# total_area              23325 non-null float64
# first_day_exposition    23325 non-null datetime64[ns]
# rooms                   23325 non-null int64
# ceiling_height          23325 non-null float64
# floors_total            23325 non-null int64
# living_area             23325 non-null float64
# floor                   23325 non-null int64
# is_apartment            23325 non-null bool
# studio                  23325 non-null bool
# open_plan               23325 non-null bool
# kitchen_area            23325 non-null float64
# balcony                 23325 non-null int64
# locality_name           23325 non-null object
# airports_nearest        17923 non-null float64
# citycenters_nearest     17946 non-null float64
# parks_around3000        23325 non-null int64
# ...

# %% [markdown]
# Мы проделали ОГРОМНУЮ работу, чтобы привести данные в порядок. Неизведанными остались только расстояние до аэропорта, расстояние до ближайшего водоема и ближайшего парка, а также расстояние до центра во всех городах кроме Санкт- Петербурга. В дальнейшем, если эти данные нам понадобятся, мы можем заменить недостающие значения на медианные, хотя это будет не совсем верно, так как отсутсвует большая часть данных и кол-во городов, поселков, деревень и т.д. имеют разные расположения и географические точности.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Предобработка данных прошла успешно. Хорошая практика давать общий вывод после шага.
# </div>

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Посчитайте и добавьте в таблицу:
# 1. цену квадратного метра
# 2. день недели, месяц и год публикации объявления
# 3. этаж квартиры (варианты- первый, последний, другой)
# 4. соотношение жилой и общей площади, а также отношение площади кухни к общей.

# %%
# Создадим параметр цены квадратного метра.
data['price_m2'] = round(data['last_price'] / data['total_area'], 2)
# день недели, месяц и год публикации объявления
data['weekday'] = data['first_day_exposition'].dt.weekday
data['month'] = data['first_day_exposition'].dt.month
data['year'] = data['first_day_exposition'].dt.year
data['first_day_exposition'] = data['first_day_exposition'].dt.date # переводим в целое число
# этаж квартиры (варианты- первый, последний, другой)
data.loc[data['floor'] == 1, 'floor_category'] = 'первый'
data.loc[data['floor'] == data['floors_total'], 'floor_category'] = 'последний'
data.loc[data['floor_category'].isna(), 'floor_category'] = 'другой'
# соотношение жилой и общей площади, а также отношение площади кухни к общей. 
data['living_area_ratio'] = round(data['living_area'] / data['total_area'], 3)
data['kitchen_area_ratio'] = round(data['kitchen_area'] / data['total_area'], 3)
data.head(15)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20    13000000      108.00           2019-03-07      3
# 1              7     3350000       40.40           2018-12-04      1
# 2             10     5196000       56.00           2015-08-20      2
# 3              0    64900000      159.00           2015-07-24      3
# 4              2    10000000      100.00           2018-06-19      2
# 5             10     2890000       30.40           2018-09-10      1
# 6              6     3700000       37.30           2017-11-02      1
# 7              5     7915000       71.60           2019-04-18      2
# 8             20     2900000       33.16           2018-05-23      1
# 9             18     5400000       61.00           2017-02-26      3
# 10             5     5050000       39.60           2017-11-16      1
# 11             9     3300000       44.00           2018-08-27      2
# 12            10     3890000       54.00           2016-06-30      2
# ...

# %% [markdown]
# Благодаря тому, что мы провели расчеты и записали их в уже имеющуюся таблицу, мы можем спокойно работать и исследовать наши данные. Переходим к самому исследованию.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Необходимые расчеты добавлены в таблицу.
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Изучим параметры площади, цены, числа комнат, высоты потолков. И построим гистограмму для каждого параметра.

# %%
data[['total_area', 'last_price', 'rooms', 'ceiling_height']].describe()
# Out:
#          total_area    last_price         rooms  ceiling_height
# count  23325.000000  2.332500e+04  23325.000000    23325.000000
# mean      60.297409  6.512273e+06      2.071640        2.718012
# std       35.514260  1.085004e+07      1.076823        0.730803
# min       13.000000  1.219000e+04      0.000000        1.000000
# 25%       40.000000  3.405000e+06      1.000000        2.600000
# 50%       52.000000  4.626540e+06      2.000000        2.650000
# 75%       69.700000  6.750000e+06      3.000000        2.700000
# max      900.000000  7.630000e+08     19.000000       32.000000

# %% [markdown]
# Исходя из данных мы видим следующее:
# -по площади есть как квартира 13 кв.м., так и 900 кв.м. Но лучше брать среднее значение;
# -по цене за квартиру - есть варианты и за 12 тысяч рублей, есть за 763 млн;
# -число комнат - от 0 (студия) до 19 (не много ли?);
# -высота потолков - от 1 до 32 метров.
#
#
# Узнаем количество строк датафрейма для того, чтоб указать выборку при прорисовке статистических графиков:

# %%
print('Выборка квартир в центральной зоне Санкт-Петербурга -', data.shape[0], 'квартир')
# Out:
# Выборка квартир в центральной зоне Санкт-Петербурга - 23325 квартир

# %% [markdown]
# Нарисуем гистограммы их распределения, но сначала определим выбросы по каждому из набора данных (что лежит за пределами "усов"):

# %%
rows = 2
cols = 2
fig, axes = plt.subplots(rows, cols, figsize=(50,25))
column_list = ['total_area', 'last_price', 'rooms', 'ceiling_height']
ylims = [600, 13000, 10, 5]
count = 0
for r in range(rows):
    for c in range(cols):
        ax = data.boxplot(column=column_list[count], ax=axes[r,c], fontsize=40)
        ax.set_ylim([0, ylims[count]])
        count += 1

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Отличная визуализация. Здорово, что используешь subplots.
# </div>

# %% [markdown]
# __Получаем следующие границы:__
#
# total_area - 20-130 кв.м.;
# last_price - 0-12 млн р.;
# rooms - 0-6 комнат;
# ceiling_height - 2,4-3,25м.

# %%
import seaborn as sns
plt.figure(figsize=(15, 18))

plt.subplot(3, 2, 1)
data['total_area'].hist(bins=50, range=(0, 130))
plt.title('Кол-во объявлений в базе в зависимости от площади')
plt.xlabel('Площадь квартиры в кв.м.')
plt.ylabel('Количество объявлений')

plt.show()

# %% [markdown]
# Гистограмма по данным "цена квартиры".

# %%
plt.figure(figsize=(15, 18))
plt.subplot(3, 2, 3)
data['last_price'].hist(bins=50, range=(0, 12000000))
plt.title('Кол-во объявлений в базе в зависимости от цены')
plt.xlabel('Цена квартиры 0-12 млн. руб.')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# Гистограмма по данным "количество комнат".

# %%
plt.figure(figsize=(15, 18))

plt.subplot(3, 2, 1)
data['rooms'].hist(bins=50, range=(0, 8))  # общий график
plt.title('Кол-во объявлений в базе в зависимости от кол-ва комнат')
plt.xlabel('Количество комнат')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# Основные продажи сосредоточены в значениях 1-4 комнаты. Картиры студии и со свободной планировкой где пользователь указал "ноль" комнат 194 шт. - менее 1%. Малый сегмент объявлений 5-7 комнат. И единичные объявления где комнат более 8 (до 19 - одна такая). Разумно рассматривать диапазон 1-5 комнат.

# %% [markdown]
# Гистограмма по данным "высота потолков"

# %%
plt.figure(figsize=(15, 18))

plt.subplot(3, 2, 1)
data['ceiling_height'].hist(bins=50, range=(2, 5))  # общий график
plt.title('Кол-во объявлений в базе в зависимости от высоты потолков')
plt.xlabel('Высота потолков')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# Квартиры с "низкими" потолками - квартиры где потолки ниже 2,2 м. "Высокие" потолки там где больше 3,3 м.

# %% [markdown]
# __Вывод:__
#
# - Гистограмма "Распределение площадей": Большая часть квартир имеет метраж от 30 до 80 кв.м., пик приходится на 50 кв.м. Есть квартиры и по 800м, но это единичные выбросы.
# - Гистограмма "Распределение цен": цена на квартиры лежит в промежутке от 3 до 12 млн. Большаячасть квартир продается за цену в промежутке между 3 и 6 млн. Опять же, есть выбросы, но ничего.
# - Распределение по количеству комнат: 2/3 квартир имеют 1 или 2 комнаты, чуть меньший процент имеют 3 комнаты и небольшое количество - 4. Есть и квартиры, имеющие больше комнат, но их процент сильно ниже.
# - Гистограмма "Распределение по высоте потолков": квартиры, в большинстве своем, имеют потолки от 2,5-2,75м (самый популярный вариант) до 3,2м. Остальные случаи - эксклюзивы.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Согласен с исследовательским анализом и выводами.
#
# </div>

# %% [markdown]
# # Шаг 5.2 (Изучение время продажи квартиры)
#
# - Построим гистограмму.
# - Посчитаем среднее и медиану.
# - Опишем, скольок обычно занимает продажа.
# - Ответим на вопрос, когда можно считать, что продажи прошли очень быстро, а когда долго?

# %%
# Посмотрим на данные и гистограмму по времени продажи квартиры:
data['days_exposition'].describe().to_frame()
# Out:
#        days_exposition
# count     20213.000000
# mean        181.055014
# std         220.010580
# min           1.000000
# 25%          45.000000
# 50%          95.000000
# 75%         232.000000
# max        1580.000000

# %% [markdown]
# Есть квартиры, которые продавались 5 лет? Вполне возможно, но, как я предполагал ранее, есть вероятность, что это те объявления, которые вовремя не были закрыты, из-за этого срок продажи не соответствует реальным и имеет очень большое значение.
# Среднее время продажи - полгода, 156 дней. Медианное - 74 дней.
# 3 месяца для продажи квартиры - очень неплохой срок.
#
# Строим гистограмму.

# %%
data['days_exposition'].hist(bins=70, figsize=(10,5), ec='black')
plt.show()

# %%
# Устанавливаем маркер 9999 для пропусков в сроке продажи и приводим к целочисленному типу
data['days_exposition'].fillna(9999, inplace=True)
data['days_exposition'] = data['days_exposition'].astype(int)

# %%
# Отбрасываем маркеры пустых значений
print('Время продажи (медиана):', round(data.query('days_exposition != 9999')['days_exposition'].median()),'\n')
print('Время продажи (среднее):', round(data.query('days_exposition != 9999')['days_exposition'].mean()),'\n')
plt.hist(data.query('days_exposition != 9999')['days_exposition'], bins=100, range=(0,250))
plt.title('Время продажи')
plt.xlabel('Дни')
plt.ylabel('Количество квартир')
plt.show()
# Изучаем значения срока продажи
data.query('days_exposition != 9999')['days_exposition'].describe()
# Out:
# Время продажи (медиана): 95
#
# Время продажи (среднее): 181
# count    20213.000000
# mean       181.055014
# std        220.010580
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Комментарий ревьювера (что можно улучшить)**
#
# Стоит убрать технические заголовки над графиком. Для этого воспользуйся plt.show() в конце ячейки.
# </div>

# %% [markdown]
# Большая часть квартир продавалась в течение первых 50 дней, есть и квартиры, которые продавались до года. Чем дальше, тем реже встречаются такие случаи.
#
# Посмотрим на boxplot:

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **Комментарий ревьювера (недочет, который нужно доработать)**
#
# Вот здесь нам и аукнулись нулевые значения, которые мы создали искусственно. Отфильтруй нулевые значения, или не заполняй пропуски в этом столбце.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: </b>
#     По итогу решила сделать немножечко хитрее, чтобы прям все не отфильтровывать. Установила маркер в "9999" для пропусков в сроке продажи.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Комментарий ревьювера v2 (что можно улучшить)**
#
# Применение значений-заглушек допустимо, только на графиках их быть не должно.
#
# </div>

# %%
data.boxplot(column='days_exposition')
plt.show()

# %% [markdown]
# Поставим ограничение по сроку продажи 500 дней, чтоб убрать выбросы. Посмотрим на данные более детально:

# %%
data.query('days_exposition<500')['days_exposition'].hist(bins=70, figsize=(10,3), ec='black')
plt.show()

# %% [markdown]
# Посмотрим ближе наши пики в 45 и 60 дней.

# %%
data.query('40<days_exposition<65')['days_exposition'].hist(bins=70, figsize=(10,3), ec='black')
plt.show()

# %% [markdown]
# Выглядит крайне странно. Но, учитывая то, что многие самостоятельно не закрывают объявления, что большая часть квартир продается в пределах 60 дней с момента публикации объявления и что проверка производится раз в 15 дней, имеем такие вот данные. На всякий случай, учтем ещё и другое количество дней, кратное 15, - 30:

# %%
data.query('25<days_exposition<65')['days_exposition'].hist(bins=70, figsize=(10,3), ec='black')
plt.show()

# %% [markdown]
# Теория подтвердилась. Но появилась новая мысль о том, что сайт автомотически убирает часть объявлений через 45 или через 60 дней.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Действительно, похоже на то.
# </div>

# %% [markdown]
# # Зависимость цены от числа комнат, этажа, удалённости от центра и даты размещения объявления
# Необходимо убрать редкие и выбивающиеся значения. Описать особенности.
# - Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от числа комнат, этажа и удалённости от центра.
#
# Для прорисовки графиков напишем функцию:

# %%
# Функция для подсчёта границ с учетом 1.5 размаха
def quartile_range(df, column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    dfq = df.loc[(df[column] < q3 + 1.5*iqr) & (df[column] > q1 - 1.5*iqr), column]
    return dfq
# Столбцы с выбросами
list_features = ['last_price', 'total_area', 'kitchen_area', 'living_area', 'days_exposition', 'ceiling_height', 'rooms']
for col in list_features:
    data[col] = quartile_range(data, col)

# Возвращаем в целочисленный тип число комнат
data['rooms'] = data['rooms'].fillna(0).astype(int)

# Изучаем, есть ли выбивающиеся значения
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23325.000000  2.129500e+04  22106.000000  23325.000000    20407.000000
# mean       9.875927  4.829144e+06     54.345328      2.015348        2.631003
# std        5.676023  2.202021e+06     19.308262      0.985978        0.081514
# min        0.000000  1.219000e+04     13.000000      0.000000        2.460000
# 25%        6.000000  3.300000e+06     39.462500      1.000000        2.600000
# 50%        9.000000  4.400000e+06     50.100000      2.000000        2.650000
# 75%       14.000000  5.990000e+06     65.500000      3.000000        2.650000
# max       50.000000  1.175759e+07    114.200000      5.000000        2.850000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23325.000000  22463.000000  23325.000000  22036.000000  23325.000000
# mean      10.670654     31.442994      5.873355      9.420890      0.591897
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **Комментарий ревьювера (недочет, который нужно доработать)**
#
# Перед определением зависимости факторов нужно отфильтровать данные от выбросов, выявленных в исследовательском анализе данных. Затем работать с очищенными данными. При этом рекомендуется не превышать долю удаленных значений в 10%.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: </b>
#     В датафрейме отброшены значения на основе 1.5 размаха. Но в дальнейшем я выбросы брала в расчет и выкидывала их, рассматривая только нужные нам значения. Но на всякий случай оставила и прошлый код (для себя).
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера v2 (все отлично)**
#
# Хорошее решение.
# </div>

# %%
def depend_price(df, column):
    title_dict = {'rooms': 'Зависимость цены от количества комнат', 'floor_category': 'Зависимость цены от этажа',
                  'day':'Медиана цен по дням недели', 'month': 'Медиана цен по месяцам',
                  'year': 'Медиана цен по годам', 'citycenters_nearest_kms': 'Зависимость цены от удаленности от центра города'}
    plt.style.use('seaborn-pastel')
    if column == 'floor_category' or column == 'citycenters_nearest_kms':
        sort_key = 'last_price'
    else:
        sort_key = column
    if column == 'citycenters_nearest':
        fontsize = 12
    else:
        fontsize = 15
    df_filtered = df.groupby(column).median()['last_price'].reset_index().sort_values(by=sort_key)
    plot = df_filtered.plot(x=column, y="last_price", kind='bar', ec='black', 
                            title=title_dict[column], legend=None, 
                            fontsize=fontsize, figsize=(9,4))
    ax2 = plt.gca()  # удалим xlabel - у нас и так есть многоговорящее название графика
    x_axis = ax2.xaxis
    x_axis.label.set_visible(False)
    if column != 'citycenters_nearest_kms':
        plt.xticks(rotation=0)
    return plot

# %% [markdown]
# Смотрим зависимость цены от количества комнат:

# %%
depend_price(data, 'rooms')

# %%
# Посмотрим на выбросы:
data.boxplot(column='rooms')

# %%
#Смотрим без выбросов:
#depend_price(data.query('rooms <= 6'), 'rooms')

# %% [markdown]
# Всё так. Чем больше комнат, тем выше цена - так продолжается до 7 комнат. Далее - единичные значения (выбросы). Вполне возможно, что дальше идут бывшие коммуналки на продажу?
#
# Теперь берёмся за этажи (по категориям: 'первый', 'последний', 'другой').

# %%
depend_price(data, 'floor_category')

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **Комментарий ревьювера (недочет, который нужно доработать)**
#
# Для параметров 'last_price', 'price_per_area', 'total_area', 'rooms', 'cityCenters_nearest' следует посчитать коэффициент корреляции Пирсона.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: </b>
#    Добавила коэффициент корреляции Пирсона.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера v2 (все отлично)**
#
# 👍
# </div>

# %%
# Зависимость цены от площади
(
    data.pivot_table(index='total_area', values='last_price')
    .plot(grid=True, style='o', figsize=(5, 5))
)
plt.show()
print('Корреляция цены и площади:','\n')
print(data.pivot_table(index='floor', values=['total_area', 'last_price']).corr(),'\n')

# Зависимость цены от числа комнат
(
    data.query('rooms > 0').pivot_table(index='rooms', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()
print('Корреляция цены и числа комнат:','\n')
print(data.query('rooms > 0').pivot_table(index='floor', values=['rooms', 'last_price']).corr(),'\n')

# Зависимость цены от удалённости от центра
(
    data.pivot_table(index='citycenters_nearest', values='last_price')
    .plot(grid=True, style='o', figsize=(5, 5))
)
plt.show()
print('Корреляция цены и удалённости от центра:','\n')
print(data.pivot_table(index='floor', values=['citycenters_nearest', 'last_price']).corr(),'\n')

# Зависимость цены от этажа
(
    data.pivot_table(index='floor_category', values='last_price', aggfunc='median')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()
# Out:
# Корреляция цены и площади:
#
#             last_price  total_area
# last_price    1.000000    0.906015
# total_area    0.906015    1.000000
# Корреляция цены и числа комнат:
#
#             last_price    rooms
# last_price     1.00000  0.53924
# rooms          0.53924  1.00000
# Корреляция цены и удалённости от центра:
#
#                      citycenters_nearest  last_price
# citycenters_nearest             1.000000    0.700219
# last_price                      0.700219    1.000000

# %% [markdown]
# 1ый этаж самый дешевый (аж на 25%), заехать на любой другой этаже будет подороже, ну и также из предыдущих записей можем сделать вывод, что чем дальше от центра, тем цена ниже.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Согласен с выводом.
# </div>

# %% [markdown]
# # Теперь исследуем зависимость цены от дня недели, месяца и года.
# Построим график зависимости средней цены от дня недели, месяца и года публикации объявления:
#
# Напишем под эти цели свою функцию:

# %%
def dmy_price(df, ylims=None):
    dmy_to_plot = ['weekday', 'month', 'year']
    titles = ['Медиана цен по дню недели', 'Медиана цен по месяцу', 'Медиана цен по году']

    for i in range(len(dmy_to_plot)):
        df_to_plot = data.groupby(dmy_to_plot[i]).median()['last_price'].reset_index().sort_values(by=dmy_to_plot[i])
        if ylims is None:
            plot = df_to_plot.plot(x=dmy_to_plot[i], y="last_price", kind='bar', figsize=(10,5), ec='black',
                                   legend=False, title=titles[i], fontsize=15)
        else:
            plot = df_to_plot.plot(x=dmy_to_plot[i], y="last_price", kind='bar', figsize=(10,5), ec='black',
                               legend=False, title=titles[i], fontsize=15, ylim=ylims[i])
        ax2 = plt.gca()
        x_axis = ax2.xaxis
        x_axis.label.set_visible(False)
        if dmy_to_plot[i] != 'weekday':
            plt.xticks(rotation=0)
    return plot

# %%
dmy_price(data)
plt.show()

# %% [markdown]
# Итог:
#
# - зависимость цены от дня недели публикации практически никак не зависит. Но в среднем цены на квартиры, объявление о продажи которых опубликовано в будний день, чуть выше, чем цена на квартиры с объявлениями, опубликованными в выходные дни;
# - зависимость цены от месяца публикации - апрель оказался самым "дорогим": цены на квартиры, чьи объявления о продаже были опубликованы в апреле, выше, чем по остальным месяцам. Особенно выделяется медиана цен на квартиры по июньским объявлениям - довольно низкие в сравнении с другими месяцами;
# - зависимость цены от года публикации - 2014г. тут очень выделяется. Рассмотрим его чуть подробнее (по месяцам) и сделаем общий вывод про зависимость цены от года публикации:

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Все верно!
# </div>

# %%
depend_price(data.query('year == 2014'), 'month')
plt.show()

# %% [markdown]
# Видим, что наши в наших данных есть информация только о 11 и 12 месяцах 2014 года (и позднее).
# Из-за ослабления рубля спрос мог превышать предложение, отсюда и цены такие.
# К декабрю всё пошло на убыль.
# В 2019г. цена стала опять расти. Предполагаю, что связано с тем, что после 5 лет застоя рынок недвижимости проснулся - больше и больше граждан могут себе позволить приобрести недвижимость. Рост спроса -> рост цен.

# %% [markdown]
# # Выберем 10 населённых пунктов
# с наибольшим числом объявлений. Посчитаем среднюю цену на квадратный метр в этих населённых пунктах, затем выделим населенные пункты с самой высокой и с самой низкой стоимостью жилья.

# %%
data_pivot_locality_name = data.pivot_table(index='locality_name', values='price_m2', aggfunc=['count', 'median'])
data_pivot_locality_name.columns = ['count', 'median']
data_pivot_locality_name.sort_values('count', ascending=False).head(10)
# Out:
#                    count      median
# locality_name
# Санкт-Петербург    15481  104629.630
# поселок Мурино       542   85714.290
# поселок Шушары       438   76747.970
# Всеволожск           390   65789.470
# Пушкин               368  100000.000
# Колпино              337   74725.270
# поселок Парголово    326   91579.710
# Гатчина              303   67647.060
# деревня Кудрово      296   91831.875
# Выборг               234   58357.385

# %% [markdown]
# Самые дорогие квартиры находятся в Санкт-Петербурге и в посёлке Мурино, при этом в Выборге средняя цена аж в 66 раз.
#
# # Изучаем предложения квартир.
# Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (locality_name). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.

# %%
flat_spb = data.query('locality_name == "Санкт-Петербург"') #выбираем только квартиры в спб
flat_spb = flat_spb.dropna(subset = ['citycenters_nearest'], inplace = False) #убираем пропуски для дальнейшей работы
flat_spb['citycenters_nearest_km'] = flat_spb.loc[:, 'citycenters_nearest'] / 1000 #добавляем столбец с км
flat_spb ['citycenters_nearest_km'] = flat_spb ['citycenters_nearest_km']. round()#округялем
flat_spb_mean_price_per_m = flat_spb['price_m2'].mean() #средняя цена кв.м
flat_spb['mean_price_for_km'] = flat_spb_mean_price_per_m / flat_spb['citycenters_nearest_km'] #средняя цена для каждого км
flat_spb. plot (x= 'citycenters_nearest_km', y = 'mean_price_for_km', kind = 'scatter', figsize=( 10, 5), grid = True)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **Комментарий ревьювера (недочет, который нужно доработать)**
#
# Стоит построить график по средней цене за километр, так будет нагляднее.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: </b>
#     График построен)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера v2 (все отлично)**
#
# Хороший график)
# </div>

# %%
#Узнаем количество строк датафрейма data_spb для того, чтоб указать выборку при прорисовке статистических графиков:

flat_spb=flat_spb.query('citycenters_nearest_km <8')
len(flat_spb)
# Out:
# 3487

# %% [markdown]
# В самом центре (в радиусе до 1 км) медианная цена на квартиру стремится к 20 млн р. Если опираться на резкое падение цены по графику, то центр ограничен радиусом в 8 км, далее медианная цена довольно заметно падает. Однако, цены на 4-7км сравнимы с ценами на квартиры, расположенные в 2 км от центра. Скорее всего на это оказывают влияния определенные элитные районы.
# Странно, что в центр также включаются объявления, рассположенные от 14 км. до центра. Будем считать, что это вброс.
#
# # Выделите сегмент квартир в центре.
# Проанализируйте территорию в 8 км. и изучим следующие параметры:
# - площадь,
# - цена,
# - число комнат,
# - высота потолков.
#
# Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Согласен с выбранным расстоянием.
# </div>

# %%
flat_spb.describe()
# Out:
#        total_images    last_price   total_area        rooms  ceiling_height  \
# count   3487.000000  2.262000e+03  2699.000000  3487.000000     1829.000000
# mean      10.219673  7.419798e+06    69.496365     2.527961        2.663488
# std        5.997363  2.132898e+06    22.447886     1.219584        0.068051
# min        0.000000  1.600000e+06    13.000000     0.000000        2.460000
# 25%        6.000000  5.800000e+06    51.000000     2.000000        2.650000
# 50%       10.000000  7.302500e+06    69.000000     3.000000        2.650000
# 75%       15.000000  9.000000e+06    86.700000     3.000000        2.650000
# max       50.000000  1.175000e+07   114.200000     5.000000        2.850000
#
#        floors_total  living_area        floor  kitchen_area      balcony  ...  \
# count   3487.000000  2871.000000  3487.000000   2817.000000  3487.000000  ...
# mean       7.103241    41.486820     4.199312     11.225655     0.320906  ...
# ...

# %%
top=flat_spb.query('citycenters_nearest_km<8')
top.head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 3              0         NaN         NaN           2015-07-24      3
# 24             8   6500000.0        97.2           2015-10-31      2
# 35             6         NaN         NaN           2017-06-26      5
# 51             7         NaN         NaN           2017-10-17      3
# 52            20         NaN         NaN           2017-09-22      0
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 3             2.65            14          NaN      9         False  ...
# 24            2.65             3         46.5      1         False  ...
# 35            2.65             5          NaN      4         False  ...
# 51             NaN             8         38.0      4         False  ...
# 52             NaN             2          NaN      2         False  ...
#
#     days_exposition   price_m2  weekday  month  year  floor_category  \
# ...

# %%
#Анализируем площадь квартир 
top['total_area'].hist(bins=40, figsize=(13,9), ec='black')
plt.show()

# %%
#Анализируем цены квартир 
top['last_price'].hist(bins=30)
plt.show()

# %%
top['rooms'].hist(bins=30)
plt.show()

# %%
top['ceiling_height'].hist(bins=30,range=(2,5))
plt.show()

# %% [markdown]
# - Распределение площадей: Большая часть квартир имеет метраж от 50 до 100 кв.м., пиков много, основные - 60, 70 и 90 кв.м.
# - Распределение цен: цена на квартиры показалась очень странной. Что-то не так.
# - Распределение по количеству комнат: Больше всего 2- и 3 комнатных квартир, чуть меньше - 4х и одно-комнатных.
# - Распределение по высоте потолков": квартиры, в большинстве своем, имеют потолки 2,7м. Ещё некоторые квартиры имеют высоту потолков от 2,5 до 3,5м. Ниже, выше - редкость.

# %%
#Исследуем зависимость цены на квартиру в центральной зоне Санкт-Петербурга от количества комнат:

depend_price(top.query('rooms <= 6'), 'rooms')
plt.show()

# %%
# Чем больше комнат, тем выше цена. В центре всё просто.
# Зависимость цены от этажа:
depend_price(top, 'floor_category')
plt.show()
# 1ый этаж самый дешевый.

# %%
# Зависимость цены от даты размещения объявления:

dmy_price(top)
plt.show()

# %% [markdown]
# Цена квартиры от дня недели, когда опубликовали объявление о продаже, почти не зависит. Зависимость по месяцу и году опубликованя объявления есть - такая же, как и по всем данным.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **Комментарий ревьювера (недочет, который нужно доработать)**
#
# Для датасета квартир из центра Санкт-Петербурга также стоит посчитать корреляцию для параметров 'last_price', 'price_per_area', 'total_area', 'rooms', 'cityCenters_nearest'.
# </div>

# %%
# Зависимость цены от площади
(
    data.pivot_table(index='total_area', values='last_price')
    .plot(grid=True, style='o', figsize=(5, 5))
)
# Зависимость цены от числа комнат
(
    flat_spb.query('(rooms > 0) & (rooms < 7)').pivot_table(index='rooms', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()
print('Корреляция цены и числа комнат:','\n')
print(top.query('(rooms > 0) & (rooms < 7)').pivot_table(index='floor', values=['rooms', 'last_price']).corr(),'\n')

# Зависимость цены от этажа
(
    top.pivot_table(index='floor_category', values='last_price', aggfunc='median')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()

# Зависимость цены за квадрат от площади
(
    top.pivot_table(index='total_area', values='mean_price_for_km')
    .plot(grid=True, style='o', figsize=(5, 5))
)
plt.show()
print('Корреляция цены за квадрат и площади:','\n')
print(top.pivot_table(index='floor', values=['total_area', 'mean_price_for_km']).corr(),'\n')


# Зависимость от дня размещения
(
    top.pivot_table(index='weekday', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()
# Зависимость от месяца размещения
(
    top.pivot_table(index='month', values='last_price')
    .plot(grid=True, style='o-', xlim=(1,12), figsize=(10, 5))
)
plt.show()
# Зависимость от года размещения
(
    top.pivot_table(index='year', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.show()
# Out:
# Корреляция цены и числа комнат:
#
#             last_price    rooms
# last_price     1.00000  0.65203
# rooms          0.65203  1.00000
# Корреляция цены за квадрат и площади:
#
#                    mean_price_for_km  total_area
# mean_price_for_km           1.000000    0.647301
# total_area                  0.647301    1.000000

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: </b>
#     Ниже проведена корреляция Пирсона по данным пунктам
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера v2 (все отлично)**
#
# Исправление принимаю.
# </div>

# %% [markdown]
# # Вывод
# 1. Зависимость цены квартиры от числа комнат в центре такая же, как и в целом по городу
# 2. В центре верхний этаж стоит практически столько же, сколько и другие этажи, кроме первого
# 3. В центре есть очень дорогие однокомнатные квартиры
# 4. В центральной зоне почти нет зависимости от удалённости от центра города. Стоимость даже немного повышается при удалении от центра - вероятно, это связано с расположением точки, которая является формальным центром города.
# 5. В центре значительно выше стоимость квартир, опубликованных в субботу и в декабре (вероятно, перед Новым годом люди хотят сделать подарок)
# 6. Стоимость квартир в центре значительно выросла в 2015 году и снизилась только в 2017 году. Это сложно объяснить, т.к. стоимость менее элитной недвижимости упала после обвала рубля в 2014 году

# %% [markdown]
# Воспользуемся функцией corr() и посмотрим, как влияют определенные параметры квартиры на её финальную цену.

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(), annot=True, cmap="Reds", fmt='.2f')

# %%
#Выделим только столбец last_price, чтоб детальней рассмотреть влияние различных параметров именно на цену:

plt.figure(figsize=(1,8))
sns.heatmap(data.corr()[['last_price']].sort_values(by='last_price', ascending=False), cmap="Blues", 
            annot=True, annot_kws={'size':12})

# %% [markdown]
# Из данных выше, мы можем сказать, что сильнее всего цена на квартиру зависит от цены за квадратный метр (практически очевидно), от общей площади квартиры (чем больше площадь, тем выше цена), от площади жилой площади и площади кухни, а также от количества комнат.
#
# Также влияние оказывает удаленность от центра - чем дальше от центра, тем ниже цена.
#
# Многие из этих параметров оказывают довольно слабое влияние, но если попробовать их объединить в одну группу, то, наверняка, можно будет построить хорошую предсказательную модель.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Комментарий ревьювера (что можно улучшить)**
#
# Можно сравнить влияние факторов для данных из центра Санкт-Петербурга.
#
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# __Изучив все данные, можем сделать следующий вывод:__
#    1. Чем больше площадь квартиры, тем выше цена
#    2. Чем больше цена за квадратный метр, тем выше цена
#    3. Чем выше доля жилой площади/площадь кухни, тем выше цена.
#    4. Чем больше комнат, тем выше цена.
#    5. На первом этаже квартира дешевле, чем на остальных.
#    6. Чем ближе к центру, тем дороже квартира.
#    7. Квартиры, размещенные к продаже в будние дни, в среднем дороже, чем размещенные в выходные. Квартиры, размещенные к продаже в летние месяцы и в октябре, в среднем дешевле, чем размещенные в любые другие месяца. В начале и в конце года цены стабильные и высокие.
#    8. Квартиры, размещенные к продаже в 2014 году, дороже всех. В 2019г. цены начали возвращаться после "кризиса" 2015-2018 годов и расти вверх.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **Комментарий ревьювера (недочет, который нужно доработать)**
#
# Все основные результаты исследования отражены. Выводы могут измениться после исправления замечаний, проконтролируй это.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: </b>
#     Выводы остаются такими же
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера v2 (все отлично)**
#
# Спасибо, что проконтролировала)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Общий комментарий ревьювера**
#
# Мне понравилась твоя работа! Вижу, что ты постаралась над проектом. Работа хорошо структурирована и отвечает на поставленные задачи. Отмечу, что хорошо подготавливаешь данные, владеешь инструментами визуализации. Но для того, чтобы принять проект, нужно исправить критические замечания. Таких замечаний немного.
#
# Также есть несколько незначительных замечаний, которые помогут тебе с будущими проектами. Думаю, что тебе их будет несложно исправить. Жду твою работу!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: </b>
#     увидела все замечания. Взяла себе на заметку желтые, исправила красные. Надеюсь, что теперь все в порядке)
# </div>
